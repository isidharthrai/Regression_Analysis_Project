# %% [markdown]
# <h3>Problem: Comparing top five companies of India in Telecommunications sector</h4>

# %% [markdown]
# Importing all the modules

# %%
import datetime as dt
import pandas as pd
import pandas_datareader as data
import matplotlib.pyplot as pt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %% [markdown]
# Specifying the Date

# %%
start = dt.datetime(2018, 1, 1)
#end = dt.datetime.today()
end = dt.datetime(2018, 6, 13)

# %% [markdown]
# Collecting the Data set

# %%
com_df1 = pd.DataFrame(data.DataReader('BSE/BOM532454', 'quandl', start=start, end=end )['Close'])    #Bharti_Airtel

# %%
com_df2 = pd.DataFrame(data.DataReader('BSE/BOM532822', 'quandl', start=start, end=end )['Close'])    #Idea_Cellular

# %%
com_df3 = pd.DataFrame(data.DataReader('BSE/BOM500483', 'quandl', start=start, end=end )['Close'])    #Tata_Comm

# %%
com_df4 = pd.DataFrame(data.DataReader('BSE/BOM532712', 'quandl', start=start, end=end )['Close'])    #Reliance_Comm

# %%
com_df5 = pd.DataFrame(data.DataReader('BSE/BOM500108', 'quandl', start=start, end=end )['Close'])    #MTNL

# %% [markdown]
# Renaming the close columns

# %%
Bharti_Airtel = com_df1.rename(columns={'Close':'Bharti_Airtel'})
Idea_Cellular = com_df2.rename(columns={'Close':'Idea_Cellular'})
Tata_Comm = com_df3.rename(columns={'Close':'Tata_Comm'})
Reliance_Comm = com_df4.rename(columns={'Close':'Reliance_Comm'})
MTNL = com_df5.rename(columns={'Close':'MTNL'})

# %% [markdown]
# Joinig all the data frames

# %%
close_df = (((Bharti_Airtel.join(Idea_Cellular, how="outer")).join(Tata_Comm, how="outer")).join(Reliance_Comm, how="outer")).join(MTNL,how="outer")

# %%
close_df
# Out:
#             Bharti_Airtel  Idea_Cellular  Tata_Comm  Reliance_Comm   MTNL
# Date
# 2018-06-13         376.10          61.65     609.25          16.05  17.70
# 2018-06-12         381.05          65.10     608.20          16.10  18.05
# 2018-06-11         388.75          63.70     607.40          15.65  16.80
# 2018-06-08         376.75          63.95     602.95          15.80  17.10
# 2018-06-07         379.95          61.50     608.15          15.75  17.70
# 2018-06-06         380.35          59.05     608.15          16.00  16.90
# 2018-06-05         363.80          56.50     603.10          14.50  15.10
# 2018-06-04         371.85          62.75     603.30          15.75  15.60
# 2018-06-01         382.60          61.65     602.20          16.45  16.05
# 2018-05-31         373.80          61.65     617.10          18.70  16.40
# 2018-05-30         375.90          61.75     630.15          17.50  16.65
# 2018-05-29         378.25          62.20     621.05          15.95  16.90
# 2018-05-28         374.20          61.20     642.15          15.30  16.80
# 2018-05-25         376.65          59.70     631.40          14.25  16.00
# 2018-05-24         371.45          56.85     614.85          14.15  15.85
# 2018-05-23         356.80          54.65     612.00          14.25  16.10
# 2018-05-22         361.90          55.00     612.25          14.40  16.25
# 2018-05-21         360.20          52.80     609.05          13.40  16.00
# 2018-05-18         361.95          52.10     609.10          15.35  16.65
# 2018-05-17         366.55          52.70     614.50          16.55  16.95
# 2018-05-16         375.35          52.75     623.65          10.55  17.20
# 2018-05-15         379.40          53.05     617.95          12.45  16.80
# 2018-05-14         381.50          51.75     634.80          13.50  16.65
# 2018-05-11         385.70          51.45     636.25          13.70  17.50
# 2018-05-10         412.25          58.35     612.45          13.95  18.00
# 2018-05-09         402.60          60.70     611.30          15.05  18.25
# 2018-05-08         400.75          61.25     613.85          15.15  18.40
# 2018-05-07         398.00          62.45     610.20          15.55  18.60
# 2018-05-04         396.60          62.50     616.15          15.35  18.55
# 2018-05-03         404.40          63.90     614.25          15.05  18.85
# ...                   ...            ...        ...            ...    ...
# 2018-02-12         424.05          84.70     649.50          27.10  23.45
# 2018-02-09         421.75          83.85     638.60          27.00  22.50
# 2018-02-08         429.50          85.65     619.95          26.55  22.95
# 2018-02-07         429.85          84.00     601.60          25.15  22.40
# 2018-02-06         438.75          84.90     601.65          24.60  20.20
# 2018-02-05         439.50          87.85     618.10          26.10  21.00
# 2018-02-02         421.80          88.15     614.35          26.10  21.85
# 2018-02-01         438.05          91.25     621.65          28.65  24.25
# 2018-01-31         439.65          93.15     615.70          29.50  25.15
# 2018-01-30         440.10          94.00     611.95          30.10  25.65
# 2018-01-29         440.55          93.60     605.95          27.25  25.85
# 2018-01-25         452.60          95.15     618.30          28.35  25.45
# 2018-01-24         458.95          94.05     634.15          28.80  25.35
# 2018-01-23         490.90          99.40     638.70          29.20  26.30
# 2018-01-22         489.70          99.60     643.60          28.70  26.10
# 2018-01-19         497.75         102.30     634.40          29.45  25.90
# 2018-01-18         494.50         100.90     633.80          29.45  26.25
# 2018-01-17         500.35         103.45     644.35          32.40  27.85
# 2018-01-16         496.90         102.60     650.35          31.25  28.30
# 2018-01-15         504.10         104.65     672.30          31.50  29.05
# 2018-01-12         509.40         108.60     676.10          31.35  27.20
# 2018-01-11         514.75         107.15     676.15          32.75  28.05
# 2018-01-10         506.35         107.50     673.00          33.15  27.55
# 2018-01-09         510.00         108.60     680.80          32.75  27.95
# 2018-01-08         516.10         109.50     678.50          33.90  29.50
# 2018-01-05         540.00         115.65     671.70          34.05  28.90
# 2018-01-04         522.45         104.50     673.90          33.35  29.30
# 2018-01-03         518.45         102.55     668.90          30.55  29.75
# 2018-01-02         516.30         100.75     670.90          32.35  30.30
# 2018-01-01         528.15         104.85     678.45          35.40  28.15
#
# [112 rows x 5 columns]

# %% [markdown]
# Finding Percentage Change of each Company according to previous day

# %%
rets = close_df.pct_change()                                    #returns -- one day percent change for each of the stocks
rets
# Out:
#             Bharti_Airtel  Idea_Cellular  Tata_Comm  Reliance_Comm      MTNL
# Date
# 2018-06-13            NaN            NaN        NaN            NaN       NaN
# 2018-06-12       0.013161       0.055961  -0.001723       0.003115  0.019774
# 2018-06-11       0.020207      -0.021505  -0.001315      -0.027950 -0.069252
# 2018-06-08      -0.030868       0.003925  -0.007326       0.009585  0.017857
# 2018-06-07       0.008494      -0.038311   0.008624      -0.003165  0.035088
# 2018-06-06       0.001053      -0.039837   0.000000       0.015873 -0.045198
# 2018-06-05      -0.043513      -0.043184  -0.008304      -0.093750 -0.106509
# 2018-06-04       0.022128       0.110619   0.000332       0.086207  0.033113
# 2018-06-01       0.028910      -0.017530  -0.001823       0.044444  0.028846
# 2018-05-31      -0.023001       0.000000   0.024743       0.136778  0.021807
# 2018-05-30       0.005618       0.001622   0.021147      -0.064171  0.015244
# 2018-05-29       0.006252       0.007287  -0.014441      -0.088571  0.015015
# 2018-05-28      -0.010707      -0.016077   0.033975      -0.040752 -0.005917
# 2018-05-25       0.006547      -0.024510  -0.016741      -0.068627 -0.047619
# 2018-05-24      -0.013806      -0.047739  -0.026212      -0.007018 -0.009375
# 2018-05-23      -0.039440      -0.038698  -0.004635       0.007067  0.015773
# 2018-05-22       0.014294       0.006404   0.000408       0.010526  0.009317
pt.xlabel("Idea_Cellular")
pt.ylabel("Bharti_Airtel")
pt.title("Correlation")
pt.savefig("1 Idea_Cellular and Bharti_Airtel.png")

# %% [markdown]
# <h3>Idea_Cellular and Tata_Comm</h3>

# %%
pt.plot(rets.Idea_Cellular, rets.Tata_Comm,'o')
pt.xlabel("Idea_Cellular")
pt.ylabel("Tata_Comm")
pt.title("Correlation")
pt.savefig("2 Idea_Cellular and Tata_Comm.png")

# %% [markdown]
# <h3>Idea_Cellular and Reliance_Comm</h3>

# %%
pt.plot(rets.Idea_Cellular,rets.Reliance_Comm,'o')
pt.xlabel("Idea_Cellular")
pt.ylabel("Reliance_Comm")
pt.title("Correlation")
pt.savefig("3 Idea_Cellular and Reliance_Comm.png")

# %% [markdown]
# <h3>Idea_Cellular and MTNL</h3>

# %%
pt.plot(rets.Idea_Cellular, rets.MTNL,'o')
pt.xlabel("Idea_Cellular")
pt.ylabel("MTNL")
pt.title("Correlation")
pt.savefig("4 Idea_Cellular and MTNL.png")

# %% [markdown]
# <h2>Correlation Matrix

# %%
rets.corr()
# Out:
#                Bharti_Airtel  Idea_Cellular  Tata_Comm  Reliance_Comm  \
# Bharti_Airtel       1.000000       0.592670   0.136473       0.117755
# Idea_Cellular       0.592670       1.000000   0.074754       0.271498
# Tata_Comm           0.136473       0.074754   1.000000       0.199425
# Reliance_Comm       0.117755       0.271498   0.199425       1.000000
# MTNL                0.135320       0.232592   0.143193       0.218552
#
#                    MTNL
# Bharti_Airtel  0.135320
# Idea_Cellular  0.232592
# Tata_Comm      0.143193
# Reliance_Comm  0.218552
# MTNL           1.000000

# %% [markdown]
# <H2> Risk Return Analysis

# %%
pt.scatter(rets.mean(), rets.std())
pt.xlabel('Expected returns')
pt.ylabel('Standard deviations/ Risks')
pt.title('Risk and Return Analysis')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    pt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'top',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.2),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

pt.savefig("5 Risk and Return Analysis.png")

# %% [markdown]
# <h3>Steps for regression</h3>
# <li>Construct y (dependent variable series)
# <li>Construct matrix (dataframe) of X (independent variable series)
# <li>Add intercept
# <li>Model the regression
# <li>Get the results
# <h3>The statsmodels library contains various regression packages. We'll use the OLS (Ordinary Least Squares) model

# %%
import numpy as np
import statsmodels.api as sm
X=close_df[['Bharti_Airtel','Tata_Comm','Reliance_Comm','MTNL']]
X = sm.add_constant(X)
y=close_df['Idea_Cellular']
model = sm.OLS(y,X,missing='drop')             #drop rows with missing values
result = model.fit()                           #adjusts the data to model
result.summary()
# Out:
# C:\Users\raisi\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Idea_Cellular   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     800.3
# Date:                Sun, 17 Jun 2018   Prob (F-statistic):           9.94e-79
# Time:                        10:28:03   Log-Likelihood:                -274.51
# No. Observations:                 112   AIC:                             559.0
# Df Residuals:                     107   BIC:                             572.6
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             2.0695     10.767      0.192      0.848     -19.274      23.413
# Bharti_Airtel     0.1475      0.017      8.512      0.000       0.113       0.182
# Tata_Comm        -0.0396      0.019     -2.098      0.038      -0.077      -0.002
# Reliance_Comm     1.4884      0.111     13.439      0.000       1.269       1.708
# MTNL              0.2299      0.280      0.820      0.414      -0.326       0.786
# ==============================================================================
# Omnibus:                        9.312   Durbin-Watson:                   0.585
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                9.849
# Skew:                          -0.726   Prob(JB):                      0.00727
# Kurtosis:                       2.999   Cond. No.                     3.01e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.01e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3>Plotting the Predicted values and actual values to the model

# %%
fig, ax = pt.subplots(figsize=(8,6))
ax.plot(y, color="#2498B0", label="Actual values")
ax.plot(result.fittedvalues, color='#f4c20d', label="Predicted values")
ax.set_xlabel('Dates')
ax.set_ylabel('Closed Prices')
ax.set_title('Idea_Cellular Predicted Values')
p,q = ax.get_legend_handles_labels()
ax.legend(p, q)
pt.savefig("6 Idea_Cellular Predicted Values")
