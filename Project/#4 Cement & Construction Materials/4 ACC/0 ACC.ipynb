# %% [markdown]
# <h3>Problem: Comparing top five companies of India in Cement & Construction Material sector</h4>

# %% [markdown]
# Importing all the modules

# %%
import datetime as dt
import pandas as pd
import pandas_datareader as data
import matplotlib.pyplot as pt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %% [markdown]
# Specifying the Date

# %%
start = dt.datetime(2018, 1, 1)
#end = dt.datetime.today()
end = dt.datetime(2018, 6, 13)

# %% [markdown]
# Collecting the Data set

# %%
com_df1 = pd.DataFrame(data.DataReader('BSE/BOM532538', 'quandl', start=start, end=end )['Close'])    #UltraTechCement

# %%
com_df2 = pd.DataFrame(data.DataReader('BSE/BOM500387', 'quandl', start=start, end=end )['Close'])    #Shree_Cements

# %%
com_df3 = pd.DataFrame(data.DataReader('BSE/BOM500425', 'quandl', start=start, end=end )['Close'])    #Ambuja_Cements

# %%
com_df4 = pd.DataFrame(data.DataReader('BSE/BOM500410', 'quandl', start=start, end=end )['Close'])    #ACC

# %%
com_df5 = pd.DataFrame(data.DataReader('BSE/BOM533309', 'quandl', start=start, end=end )['Close'])    #Dalmia_Bharat

# %% [markdown]
# Renaming the close columns

# %%
UltraTechCement = com_df1.rename(columns={'Close':'UltraTechCement'})
Shree_Cements = com_df2.rename(columns={'Close':'Shree_Cements'})
Ambuja_Cements = com_df3.rename(columns={'Close':'Ambuja_Cements'})
ACC = com_df4.rename(columns={'Close':'ACC'})
Dalmia_Bharat = com_df5.rename(columns={'Close':'Dalmia_Bharat'})

# %% [markdown]
# Joinig all the data frames

# %%
close_df = (((UltraTechCement.join(Shree_Cements, how="outer")).join(Ambuja_Cements, how="outer")).join(ACC, how="outer")).join(Dalmia_Bharat,how="outer")

# %%
close_df
# Out:
#             UltraTechCement  Shree_Cements  Ambuja_Cements      ACC  \
# Date
# 2018-06-13          3798.15       16311.10          209.45  1331.00
# 2018-06-12          3768.25       16228.95          206.90  1316.85
# 2018-06-11          3780.35       16663.30          205.90  1320.40
# 2018-06-08          3713.40       16151.15          205.60  1314.70
# 2018-06-07          3718.90       16306.30          205.80  1314.90
# 2018-06-06          3697.85       16135.95          204.05  1317.10
# 2018-06-05          3671.85       16063.20          202.00  1283.50
# 2018-06-04          3711.50       16364.45          201.75  1309.55
# 2018-06-01          3685.90       16599.95          203.40  1329.60
# 2018-05-31          3734.70       16836.65          205.20  1356.20
# 2018-05-30          3711.65       16776.60          206.00  1306.50
# 2018-05-29          3712.50       16783.35          208.55  1309.80
# 2018-05-28          3732.05       16791.45          212.65  1324.10
# 2018-05-25          3683.95       16197.15          211.90  1326.25
# 2018-05-24          3658.00       16123.15          212.30  1332.50
# 2018-05-23          3700.10       16016.70          207.10  1313.00
# 2018-05-22          3756.00       16383.25          208.20  1327.25
# 2018-05-21          3851.65       16075.20          208.05  1344.90
# 2018-05-18          3859.30       16304.55          211.65  1374.80
# 2018-05-17          3953.85       16383.65          217.00  1400.15
# 2018-05-16          3987.70       16474.40          211.35  1410.60
# 2018-05-15          4120.10       16436.05          214.55  1411.75
# 2018-05-14          4094.85       16134.85          217.65  1448.10
# 2018-05-11          4063.15       16255.85          217.35  1471.00
# 2018-05-10          3996.75       16112.20          220.40  1495.60
# 2018-05-09          3965.20       16329.60          225.15  1510.60
# 2018-05-08          4063.55       16506.75          230.00  1519.35
# 2018-05-07          4027.80       16557.75          235.05  1525.75
# 2018-05-04          3988.95       16365.75          236.95  1530.35
# 2018-05-03          3999.55       16658.40          240.45  1538.90
# ...                     ...            ...             ...      ...
# 2018-02-12          4200.75       16937.10          257.10  1651.10
# 2018-02-09          4154.75       16971.15          258.50  1659.40
# 2018-02-08          4158.55       16983.40          261.65  1692.30
# 2018-02-07          4081.30       16920.35          245.40  1590.30
# 2018-02-06          4093.85       16904.95          255.00  1618.10
# 2018-02-05          4138.10       16629.55          259.20  1643.85
# 2018-02-02          4177.90       17046.10          259.30  1676.25
# 2018-02-01          4389.40       17423.30          264.85  1733.05
# 2018-01-31          4379.90       17212.45          261.05  1716.40
# 2018-01-30          4360.90       17282.55          260.95  1729.50
# 2018-01-29          4387.40       17819.90          263.60  1737.20
# 2018-01-25          4355.25       18145.35          263.15  1727.45
# 2018-01-24          4283.75       18204.35          260.30  1744.85
# 2018-01-23          4368.10       18367.70          263.00  1793.95
# 2018-01-22          4330.05       18402.80          268.80  1829.10
# 2018-01-19          4300.20       18365.75          268.50  1822.70
# 2018-01-18          4408.55       18450.10          275.95  1837.55
# 2018-01-17          4542.50       18933.10          276.45  1840.25
# 2018-01-16          4543.90       19094.15          276.60  1848.95
# 2018-01-15          4524.95       19094.95          277.05  1826.75
# 2018-01-12          4391.25       18856.50          269.65  1805.15
# 2018-01-11          4396.50       19511.95          272.25  1801.30
# 2018-01-10          4393.05       19474.90          276.05  1811.90
# 2018-01-09          4415.55       19423.60          276.85  1813.00
# 2018-01-08          4410.80       19370.85          274.25  1818.05
# 2018-01-05          4395.55       19018.10          274.00  1805.70
# 2018-01-04          4340.95       18059.15          273.95  1799.70
# 2018-01-03          4294.50       18106.85          272.25  1770.05
# 2018-01-02          4255.05       17950.55          267.65  1736.60
# 2018-01-01          4257.50       17881.15          267.55  1735.15
#
#             Dalmia_Bharat
# Date
# 2018-06-13        2518.90
# 2018-06-12        2504.95
# 2018-06-11        2594.85
# 2018-06-08        2575.25
# 2018-06-07        2652.30
# 2018-06-06        2542.35
# 2018-06-05        2615.10
# 2018-06-04        2697.85
# 2018-06-01        2703.80
# 2018-05-31        2731.40
# 2018-05-30        2714.15
# 2018-05-29        2747.35
# 2018-05-28        2693.00
# 2018-05-25        2641.65
# 2018-05-24        2562.70
# 2018-05-23        2704.35
# 2018-05-22        2731.30
# 2018-05-21        2736.45
# 2018-05-18        2694.30
# 2018-05-17        2746.75
# 2018-05-16        2756.05
# 2018-05-15        2736.95
# 2018-05-14        2748.30
# 2018-05-11        2797.65
# 2018-05-10        2759.95
# 2018-05-09        2770.00
# 2018-05-08        2863.15
# 2018-05-07        2880.45
# 2018-05-04        2850.30
# 2018-05-03        2945.35
# ...                   ...
# 2018-02-12        2882.90
# 2018-02-09        2787.05
# 2018-02-08        2795.35
# 2018-02-07        2704.50
# 2018-02-06        2717.75
# 2018-02-05        2727.80
# 2018-02-02        2820.85
# 2018-02-01        2980.70
# 2018-01-31        2930.45
# 2018-01-30        2936.10
# 2018-01-29        2980.25
# 2018-01-25        2998.65
# 2018-01-24        3004.60
# 2018-01-23        3022.00
# 2018-01-22        2986.80
# 2018-01-19        3027.45
# 2018-01-18        3092.40
# 2018-01-17        3134.30
# 2018-01-16        3119.45
# 2018-01-15        3171.50
# 2018-01-12        3188.00
# 2018-01-11        3170.00
# 2018-01-10        3169.80
# 2018-01-09        3192.95
# 2018-01-08        3117.65
# 2018-01-05        3100.20
# 2018-01-04        3102.75
# 2018-01-03        3101.60
# 2018-01-02        3114.70
# 2018-01-01        3186.10
#
# [112 rows x 5 columns]

# %% [markdown]
# Finding Percentage Change of each Company according to previous day

# %%
rets = close_df.pct_change()                                    #returns -- one day percent change for each of the stocks
rets
# Out:
#             UltraTechCement  Shree_Cements  Ambuja_Cements       ACC  \
# Date
# 2018-06-13              NaN            NaN             NaN       NaN
# 2018-06-12        -0.007872      -0.005036       -0.012175 -0.010631
# 2018-06-11         0.003211       0.026764       -0.004833  0.002696
# 2018-06-08        -0.017710      -0.030735       -0.001457 -0.004317
# 2018-06-07         0.001481       0.009606        0.000973  0.000152
# 2018-06-06        -0.005660      -0.010447       -0.008503  0.001673
# 2018-06-05        -0.007031      -0.004509       -0.010047 -0.025511
# 2018-06-04         0.010798       0.018754       -0.001238  0.020296
# 2018-06-01        -0.006897       0.014391        0.008178  0.015311
# 2018-05-31         0.013240       0.014259        0.008850  0.020006
# 2018-05-30        -0.006172      -0.003567        0.003899 -0.036647
# 2018-05-29         0.000229       0.000402        0.012379  0.002526
# 2018-05-28         0.005266       0.000483        0.019660  0.010918
# 2018-05-25        -0.012888      -0.035393       -0.003527  0.001624
# 2018-05-24        -0.007044      -0.004569        0.001888  0.004713
# 2018-05-23         0.011509      -0.006602       -0.024494 -0.014634
# 2018-05-22         0.015108       0.022885        0.005311  0.010853
# 2018-05-21         0.025466      -0.018803       -0.000720  0.013298
# 2018-05-18         0.001986       0.014267        0.017304  0.022232
# 2018-05-17         0.024499       0.004851        0.025278  0.018439
# 2018-05-16         0.008561       0.005539       -0.026037  0.007463
# 2018-05-15         0.033202      -0.002328        0.015141  0.000815
# 2018-05-14        -0.006128      -0.018326        0.014449  0.025748
# 2018-05-11        -0.007741       0.007499       -0.001378  0.015814
# 2018-05-10        -0.016342      -0.008837        0.014033  0.016723
# 2018-05-09        -0.007894       0.013493        0.021552  0.010029
# 2018-05-08         0.024803       0.010848        0.021541  0.005792
# 2018-05-07        -0.008798       0.003090        0.021957  0.004212
# 2018-05-04        -0.009645      -0.011596        0.008083  0.003015
# 2018-05-03         0.002657       0.017882        0.014771  0.005587
# ...                     ...            ...             ...       ...
# 2018-02-12         0.007265       0.006077        0.012205  0.015593
# 2018-02-09        -0.010950       0.002010        0.005445  0.005027
# 2018-02-08         0.000915       0.000722        0.012186  0.019826
# 2018-02-07        -0.018576      -0.003712       -0.062106 -0.060273
# 2018-02-06         0.003075      -0.000910        0.039120  0.017481
# 2018-02-05         0.010809      -0.016291        0.016471  0.015914
# 2018-02-02         0.009618       0.025049        0.000386  0.019710
# 2018-02-01         0.050624       0.022128        0.021404  0.033885
# 2018-01-31        -0.002164      -0.012102       -0.014348 -0.009607
# 2018-01-30        -0.004338       0.004073       -0.000383  0.007632
# 2018-01-29         0.006077       0.031092        0.010155  0.004452
# 2018-01-25        -0.007328       0.018263       -0.001707 -0.005612
# 2018-01-24        -0.016417       0.003252       -0.010830  0.010073
# 2018-01-23         0.019691       0.008973        0.010373  0.028140
# 2018-01-22        -0.008711       0.001911        0.022053  0.019594
# 2018-01-19        -0.006894      -0.002013       -0.001116 -0.003499
# 2018-01-18         0.025197       0.004593        0.027747  0.008147
# 2018-01-17         0.030384       0.026179        0.001812  0.001469
# 2018-01-16         0.000308       0.008506        0.000543  0.004728
# 2018-01-15        -0.004170       0.000042        0.001627 -0.012007
# 2018-01-12        -0.029547      -0.012488       -0.026710 -0.011824
# 2018-01-11         0.001196       0.034760        0.009642 -0.002133
# 2018-01-10        -0.000785      -0.001899        0.013958  0.005885
# 2018-01-09         0.005122      -0.002634        0.002898  0.000607
# 2018-01-08        -0.001076      -0.002716       -0.009391  0.002785
# 2018-01-05        -0.003457      -0.018210       -0.000912 -0.006793
# 2018-01-04        -0.012422      -0.050423       -0.000182 -0.003323
# 2018-01-03        -0.010700       0.002641       -0.006206 -0.016475
# 2018-01-02        -0.009186      -0.008632       -0.016896 -0.018898
# 2018-01-01         0.000576      -0.003866       -0.000374 -0.000835
#
#             Dalmia_Bharat
# Date
# 2018-06-13            NaN
# 2018-06-12      -0.005538
# 2018-06-11       0.035889
# 2018-06-08      -0.007553
# 2018-06-07       0.029919
# 2018-06-06      -0.041455
# 2018-06-05       0.028615
# 2018-06-04       0.031643
# 2018-06-01       0.002205
# 2018-05-31       0.010208
# 2018-05-30      -0.006315
# 2018-05-29       0.012232
# 2018-05-28      -0.019783
# 2018-05-25      -0.019068
# 2018-05-24      -0.029887
# 2018-05-23       0.055274
# 2018-05-22       0.009965
# 2018-05-21       0.001886
# 2018-05-18      -0.015403
# 2018-05-17       0.019467
# 2018-05-16       0.003386
# 2018-05-15      -0.006930
# 2018-05-14       0.004147
# 2018-05-11       0.017957
# 2018-05-10      -0.013476
# 2018-05-09       0.003641
# 2018-05-08       0.033628
# 2018-05-07       0.006042
# 2018-05-04      -0.010467
# 2018-05-03       0.033347
# ...                   ...
# 2018-02-12       0.004145
# 2018-02-09      -0.033248
# 2018-02-08       0.002978
# 2018-02-07      -0.032500
# 2018-02-06       0.004899
# 2018-02-05       0.003698
# 2018-02-02       0.034112
# 2018-02-01       0.056667
# 2018-01-31      -0.016858
# 2018-01-30       0.001928
# 2018-01-29       0.015037
# 2018-01-25       0.006174
# 2018-01-24       0.001984
# 2018-01-23       0.005791
# 2018-01-22      -0.011648
# 2018-01-19       0.013610
# 2018-01-18       0.021454
# 2018-01-17       0.013549
# 2018-01-16      -0.004738
# 2018-01-15       0.016686
# 2018-01-12       0.005203
# 2018-01-11      -0.005646
# 2018-01-10      -0.000063
# 2018-01-09       0.007303
# 2018-01-08      -0.023583
# 2018-01-05      -0.005597
# 2018-01-04       0.000823
# 2018-01-03      -0.000371
# 2018-01-02       0.004224
# 2018-01-01       0.022924
#
# [112 rows x 5 columns]

# %% [markdown]
# <h2>Relationship between ACC and other companies

# %% [markdown]
# <h3>ACC and UltraTechCements</h3>

# %%
pt.plot(rets.ACC,rets.UltraTechCement, 'o')
pt.xlabel("ACC")
pt.ylabel("UltraTechCement")
pt.title("Correlation")
pt.savefig("1 ACC and UltraTechCement.png")

# %% [markdown]
# <h3>ACC and Shree Cements</h3>

# %%
pt.plot( rets.ACC,rets.Shree_Cements,'o')
pt.xlabel("ACC")
pt.ylabel("Shree_Cements")
pt.title("Correlation")
pt.savefig("2 ACC and Shree_Cements.png")

# %% [markdown]
# <h3>ACC and Ambuja Cements</h3>

# %%
pt.plot(rets.ACC,rets.Ambuja_Cements,'o')
pt.xlabel("ACC")
pt.ylabel("Ambuja_Cements")
pt.title("Correlation")
pt.savefig("3 ACC and Ambuja_Cements.png")

# %% [markdown]
# <h3>ACC and Dalmia Bharat</h3>

# %%
pt.plot(rets.ACC,rets.Dalmia_Bharat, 'o')
pt.xlabel("ACC")
pt.ylabel("Dalmia_Bharat")
pt.title("Correlation")
pt.savefig("4 ACC and Dalmia_Bharat.png")

# %% [markdown]
# <h2>Correlation Matrix

# %%
rets.corr()
# Out:
#                  UltraTechCement  Shree_Cements  Ambuja_Cements       ACC  \
# UltraTechCement         1.000000       0.402155        0.454467  0.478497
# Shree_Cements           0.402155       1.000000        0.275488  0.304224
# Ambuja_Cements          0.454467       0.275488        1.000000  0.717646
# ACC                     0.478497       0.304224        0.717646  1.000000
# Dalmia_Bharat           0.447801       0.327596        0.198235  0.209981
#
#                  Dalmia_Bharat
# UltraTechCement       0.447801
# Shree_Cements         0.327596
# Ambuja_Cements        0.198235
# ACC                   0.209981
# Dalmia_Bharat         1.000000

# %% [markdown]
# <H2> Risk Return Analysis

# %%
fig, ax = pt.subplots(figsize=(8,6))
pt.scatter(rets.mean(), rets.std())
pt.xlabel('Expected returns')
pt.ylabel('Standard deviations/ Risks')
pt.title('Risk and Return Analysis')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    pt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'top',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.2),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

pt.savefig("5 Risk and Return Analysis.png")

# %% [markdown]
# <h3>Steps for regression</h3>
# <li>Construct y (dependent variable series)
# <li>Construct matrix (dataframe) of X (independent variable series)
# <li>Add intercept
# <li>Model the regression
# <li>Get the results
# <h3>The statsmodels library contains various regression packages. We'll use the OLS (Ordinary Least Squares) model

# %%
import numpy as np
import statsmodels.api as sm
X=close_df[['UltraTechCement','Shree_Cements','Ambuja_Cements','Dalmia_Bharat']]
X = sm.add_constant(X)
y=close_df['ACC']
model = sm.OLS(y,X,missing='drop')             #drop rows with missing values
result = model.fit()                           #adjusts the data to model
result.summary()
# Out:
# C:\Users\raisi\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ACC   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     815.6
# Date:                Sat, 16 Jun 2018   Prob (F-statistic):           3.71e-79
# Time:                        15:29:43   Log-Likelihood:                -527.14
# No. Observations:                 112   AIC:                             1064.
# Df Residuals:                     107   BIC:                             1078.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            -520.3652     69.664     -7.470      0.000    -658.467    -382.264
# UltraTechCement     0.1878      0.030      6.267      0.000       0.128       0.247
# Shree_Cements       0.0020      0.006      0.359      0.720      -0.009       0.013
# Ambuja_Cements      4.7061      0.298     15.776      0.000       4.115       5.297
# Dalmia_Bharat       0.0554      0.029      1.909      0.059      -0.002       0.113
# ==============================================================================
# Omnibus:                        7.576   Durbin-Watson:                   0.423
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                7.313
# Skew:                           0.613   Prob(JB):                       0.0258
# Kurtosis:                       3.257   Cond. No.                     4.77e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3>Plotting the Predicted values and actual values to the model

# %%
fig, ax = pt.subplots(figsize=(8,6))
ax.plot(y, color="#2498B0", label="Actual values")
ax.plot(result.fittedvalues, color='#f4c20d', label="Predicted values")
ax.set_xlabel('Dates')
ax.set_ylabel('Closed Prices')
ax.set_title('ACC Predicted Values')
p,q = ax.get_legend_handles_labels()
ax.legend(p, q)
pt.savefig("6 ACC Predicted Values")
