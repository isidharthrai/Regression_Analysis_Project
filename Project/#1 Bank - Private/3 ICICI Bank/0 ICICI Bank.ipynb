# %% [markdown]
# <h3>Problem: Comparing top five companies of India in Bank-Private sector</h4>

# %% [markdown]
# Importing all the modules

# %%
import datetime as dt
import pandas as pd
import pandas_datareader as data
import matplotlib.pyplot as pt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %% [markdown]
# Specifying the Date

# %%
start = dt.datetime(2018, 1, 1)
#end = dt.datetime.today()
end = dt.datetime(2018, 6, 13)

# %% [markdown]
# Collecting the Data set

# %%
com_df1 = pd.DataFrame(data.DataReader('BSE/BOM500180', 'quandl', start=start, end=end )['Close'])    #HDFC_Bank

# %%
com_df2 = pd.DataFrame(data.DataReader('BSE/BOM500247', 'quandl', start=start, end=end )['Close'])    #Kotak_Mahindra

# %%
com_df3 = pd.DataFrame(data.DataReader('BSE/BOM532174', 'quandl', start=start, end=end )['Close'])    #ICICI_Bank

# %%
com_df4 = pd.DataFrame(data.DataReader('BSE/BOM532215', 'quandl', start=start, end=end )['Close'])    #Axis_Bank

# %%
com_df5 = pd.DataFrame(data.DataReader('BSE/BOM532187', 'quandl', start=start, end=end )['Close'])    #Indusind_Bank

# %% [markdown]
# Renaming the close columns

# %%
HDFC_Bank = com_df1.rename(columns={'Close':'HDFC_Bank'})
Kotak_Mahindra = com_df2.rename(columns={'Close':'Kotak_Mahindra'})
ICICI_Bank = com_df3.rename(columns={'Close':'ICICI_Bank'})
AXIS_Bank = com_df4.rename(columns={'Close':'AXIS_Bank'})
Indusind_Bank = com_df5.rename(columns={'Close':'Indusind_Bank'})

# %% [markdown]
# Joinig all the data frames

# %%
close_df = (((HDFC_Bank.join(Kotak_Mahindra, how="outer")).join(ICICI_Bank, how="outer")).join(AXIS_Bank, how="outer")).join(Indusind_Bank,how="outer")

# %%
close_df
# Out:
#             HDFC_Bank  Kotak_Mahindra  ICICI_Bank  AXIS_Bank  Indusind_Bank
# Date
# 2018-06-13    2035.25         1326.25      290.80     539.75        1947.10
# 2018-06-12    2044.75         1331.35      287.25     536.80        1956.15
# 2018-06-11    2045.15         1320.30      286.75     540.10        1904.50
# 2018-06-08    2050.10         1318.80      288.30     536.45        1890.05
# 2018-06-07    2064.85         1308.45      290.95     542.15        1904.70
# 2018-06-06    2059.15         1316.00      283.80     530.20        1915.90
# 2018-06-05    2060.55         1304.25      283.90     529.80        1901.65
# 2018-06-04    2046.55         1303.95      286.20     536.05        1897.10
# 2018-06-01    2109.55         1318.80      289.50     537.15        1914.95
# 2018-05-31    2136.15         1337.00      285.60     543.30        1948.00
# 2018-05-30    2046.85         1302.15      285.25     539.90        1888.75
# 2018-05-29    2032.75         1283.15      290.65     545.90        1877.55
# 2018-05-28    2042.30         1301.15      299.25     546.45        1917.45
# 2018-05-25    2011.65         1298.25      296.50     538.45        1914.75
# 2018-05-24    1985.90         1275.55      297.25     534.45        1871.20
# 2018-05-23    1966.95         1255.80      291.70     520.35        1856.70
# 2018-05-22    1991.15         1264.40      290.75     523.30        1910.25
# 2018-05-21    1991.90         1273.90      289.65     528.70        1921.30
# 2018-05-18    2012.90         1294.25      286.40     532.70        1926.20
# 2018-05-17    2027.40         1269.00      295.90     539.50        1913.25
# 2018-05-16    2024.45         1281.75      297.90     549.35        1926.90
# 2018-05-15    2039.20         1282.15      308.00     549.45        1917.50
# 2018-05-14    2021.20         1268.95      309.95     552.25        1914.45
# 2018-05-11    2010.65         1265.45      311.10     553.20        1894.15
# 2018-05-10    1989.70         1247.25      307.00     547.65        1886.05
# 2018-05-09    1979.00         1248.35      307.10     548.60        1871.85
# 2018-05-08    1966.60         1241.40      309.25     541.25        1867.60
# 2018-05-07    1979.75         1244.55      289.40     534.95        1884.85
# 2018-05-04    1987.85         1231.55      282.90     520.30        1886.65
# 2018-05-03    1967.55         1233.40      281.80     532.40        1877.75
# ...               ...             ...         ...        ...            ...
# 2018-02-12    1876.55         1042.80      326.00     562.80        1686.45
# 2018-02-09    1852.60         1032.60      326.75     557.50        1651.40
# 2018-02-08    1880.05         1050.00      334.55     568.50        1669.75
# 2018-02-07    1871.40         1034.95      332.25     558.70        1663.10
# 2018-02-06    1897.45         1033.55      330.75     564.10        1674.60
# 2018-02-05    1913.95         1062.25      331.65     566.10        1714.25
# 2018-02-02    1948.80         1087.45      334.80     564.95        1755.60
# 2018-02-01    1992.25         1120.30      345.75     590.20        1797.00
# 2018-01-31    2006.35         1109.75      352.95     593.40        1754.15
# 2018-01-30    1998.85         1089.55      352.60     593.40        1736.70
# 2018-01-29    1999.55         1113.50      357.30     605.40        1740.75
# 2018-01-25    1970.25         1091.45      358.30     613.75        1729.00
# 2018-01-24    1959.70         1080.70      352.65     607.90        1718.20
# 2018-01-23    1951.30         1074.30      362.05     618.90        1722.90
# 2018-01-22    1963.80         1071.30      351.30     611.05        1683.00
# 2018-01-19    1951.20         1059.95      353.55     590.25        1683.30
# 2018-01-18    1931.80         1045.40      346.10     583.70        1679.50
# 2018-01-17    1891.10         1027.20      343.10     584.75        1657.00
# 2018-01-16    1903.70         1032.60      334.15     558.75        1664.65
# 2018-01-15    1894.65         1039.15      329.45     560.70        1681.50
# 2018-01-12    1865.65         1019.40      317.60     555.75        1705.50
# 2018-01-11    1870.10         1017.85      309.45     558.25        1698.60
# 2018-01-10    1862.50         1001.75      312.00     562.55        1734.75
# 2018-01-09    1863.55         1006.35      312.15     565.15        1723.25
# 2018-01-08    1859.70         1006.50      314.15     565.35        1718.20
# 2018-01-05    1860.45         1003.05      312.60     563.10        1698.50
# 2018-01-04    1857.30         1000.30      314.80     559.30        1646.30
# 2018-01-03    1852.65         1000.05      315.05     560.35        1630.30
# 2018-01-02    1872.70         1002.60      309.25     559.70        1643.65
# 2018-01-01    1857.00         1001.65      310.55     564.85        1626.25
#
# [112 rows x 5 columns]

# %% [markdown]
# Finding Percentage Change of each Company according to previous day

# %%
rets = close_df.pct_change()                                    #returns -- one day percent change for each of the stocks
rets
# Out:
#             HDFC_Bank  Kotak_Mahindra  ICICI_Bank  AXIS_Bank  Indusind_Bank
# Date
# 2018-06-13        NaN             NaN         NaN        NaN            NaN
# 2018-06-12   0.004668        0.003845   -0.012208  -0.005465       0.004648
# 2018-06-11   0.000196       -0.008300   -0.001741   0.006148      -0.026404
# 2018-06-08   0.002420       -0.001136    0.005405  -0.006758      -0.007587
# 2018-06-07   0.007195       -0.007848    0.009192   0.010625       0.007751
# 2018-06-06  -0.002760        0.005770   -0.024575  -0.022042       0.005880
# 2018-06-05   0.000680       -0.008929    0.000352  -0.000754      -0.007438
# 2018-06-04  -0.006794       -0.000230    0.008101   0.011797      -0.002393
# 2018-06-01   0.030784        0.011388    0.011530   0.002052       0.009409
# 2018-05-31   0.012609        0.013800   -0.013472   0.011449       0.017259
# 2018-05-30  -0.041804       -0.026066   -0.001225  -0.006258      -0.030416
# 2018-05-29  -0.006889       -0.014591    0.018931   0.011113      -0.005930
# 2018-05-28   0.004698        0.014028    0.029589   0.001008       0.021251
# 2018-05-25  -0.015008       -0.002229   -0.009190  -0.014640      -0.001408
# 2018-05-24  -0.012800       -0.017485    0.002530  -0.007429      -0.022744
# 2018-05-23  -0.009542       -0.015484   -0.018671  -0.026382      -0.007749
# 2018-05-22   0.012303        0.006848   -0.003257   0.005669       0.028841
# 2018-05-21   0.000377        0.007513   -0.003783   0.010319       0.005785
# 2018-05-18   0.010543        0.015975   -0.011220   0.007566       0.002550
# 2018-05-17   0.007204       -0.019509    0.033170   0.012765      -0.006723
# 2018-05-16  -0.001455        0.010047    0.006759   0.018258       0.007134
# 2018-05-15   0.007286        0.000312    0.033904   0.000182      -0.004878
# 2018-05-14  -0.008827       -0.010295    0.006331   0.005096      -0.001591
# 2018-05-11  -0.005220       -0.002758    0.003710   0.001720      -0.010604
# 2018-05-10  -0.010420       -0.014382   -0.013179  -0.010033      -0.004276
# 2018-05-09  -0.005378        0.000882    0.000326   0.001735      -0.007529
# 2018-05-08  -0.006266       -0.005567    0.007001  -0.013398      -0.002270
# 2018-05-07   0.006687        0.002537   -0.064188  -0.011640       0.009236
# 2018-05-04   0.004091       -0.010446   -0.022460  -0.027386       0.000955
# 2018-05-03  -0.010212        0.001502   -0.003888   0.023256      -0.004717
# ...               ...             ...         ...        ...            ...
# 2018-02-12  -0.004139       -0.001866    0.023387   0.034654      -0.003221
# 2018-02-09  -0.012763       -0.009781    0.002301  -0.009417      -0.020783
# 2018-02-08   0.014817        0.016851    0.023871   0.019731       0.011112
# 2018-02-07  -0.004601       -0.014333   -0.006875  -0.017238      -0.003983
# 2018-02-06   0.013920       -0.001353   -0.004515   0.009665       0.006915
# 2018-02-05   0.008696        0.027768    0.002721   0.003545       0.023677
# 2018-02-02   0.018208        0.023723    0.009498  -0.002031       0.024121
# 2018-02-01   0.022296        0.030208    0.032706   0.044694       0.023582
# 2018-01-31   0.007077       -0.009417    0.020824   0.005422      -0.023845
# 2018-01-30  -0.003738       -0.018202   -0.000992   0.000000      -0.009948
# 2018-01-29   0.000350        0.021982    0.013330   0.020222       0.002332
# 2018-01-25  -0.014653       -0.019802    0.002799   0.013793      -0.006750
# 2018-01-24  -0.005355       -0.009849   -0.015769  -0.009532      -0.006246
# 2018-01-23  -0.004286       -0.005922    0.026655   0.018095       0.002735
# 2018-01-22   0.006406       -0.002793   -0.029692  -0.012684      -0.023159
# 2018-01-19  -0.006416       -0.010595    0.006405  -0.034040       0.000178
# 2018-01-18  -0.009943       -0.013727   -0.021072  -0.011097      -0.002257
# 2018-01-17  -0.021068       -0.017410   -0.008668   0.001799      -0.013397
# 2018-01-16   0.006663        0.005257   -0.026086  -0.044463       0.004617
# 2018-01-15  -0.004754        0.006343   -0.014066   0.003490       0.010122
# 2018-01-12  -0.015306       -0.019006   -0.035969  -0.008828       0.014273
# 2018-01-11   0.002385       -0.001521   -0.025661   0.004498      -0.004046
# 2018-01-10  -0.004064       -0.015818    0.008240   0.007703       0.021282
# 2018-01-09   0.000564        0.004592    0.000481   0.004622      -0.006629
# 2018-01-08  -0.002066        0.000149    0.006407   0.000354      -0.002931
# 2018-01-05   0.000403       -0.003428   -0.004934  -0.003980      -0.011465
# 2018-01-04  -0.001693       -0.002742    0.007038  -0.006748      -0.030733
# 2018-01-03  -0.002504       -0.000250    0.000794   0.001877      -0.009719
# 2018-01-02   0.010822        0.002550   -0.018410  -0.001160       0.008189
# 2018-01-01  -0.008384       -0.000948    0.004204   0.009201      -0.010586
#
# [112 rows x 5 columns]

# %% [markdown]
# <h2>Relationship between ICICI Bank and other companies

# %% [markdown]
# <h3>ICICI Bank and HDFC Bank</h3>

# %%
pt.plot(rets.ICICI_Bank,rets.HDFC_Bank, 'o')
pt.xlabel("ICICI Bank")
pt.ylabel("HDFC Bank")
pt.title("Correlation")
pt.savefig("1 ICICI Bank and HDFC Bank.png")

# %% [markdown]
# <h3>ICICI BANK and Kotak Mahindra</h3>

# %%
pt.plot( rets.ICICI_Bank,rets.Kotak_Mahindra,'o')
pt.xlabel("ICICI Bank")
pt.ylabel("Kotak Mahindra")
pt.title("Correlation")
pt.savefig("2 ICICI Bank and Kotak Mahindra.png")

# %% [markdown]
# <h3>ICICI Bank and Axis Bank</h3>

# %%
pt.plot(rets.ICICI_Bank,rets.AXIS_Bank,'o')
pt.xlabel("ICICI bank")
pt.ylabel("AXIS Bank")
pt.title("Correlation")
pt.savefig("3 ICICI Bank and AXIS Bank.png")

# %% [markdown]
# <h3>ICICI Bank and Indusind Bank</h3>

# %%
pt.plot(rets.ICICI_Bank, rets.Indusind_Bank,'o')
pt.xlabel("ICICI Bank")
pt.ylabel("Indusind Bank")
pt.title("Correlation")
pt.savefig("4 ICICI Bank and Indusind Bank.png")

# %% [markdown]
# <h2>Correlation Matrix

# %%
rets.corr()
# Out:
#                 HDFC_Bank  Kotak_Mahindra  ICICI_Bank  AXIS_Bank  \
# HDFC_Bank        1.000000        0.624962    0.142868   0.186834
# Kotak_Mahindra   0.624962        1.000000    0.015529   0.212057
# ICICI_Bank       0.142868        0.015529    1.000000   0.607516
# AXIS_Bank        0.186834        0.212057    0.607516   1.000000
# Indusind_Bank    0.430485        0.474334    0.091036   0.220274
#
#                 Indusind_Bank
# HDFC_Bank            0.430485
# Kotak_Mahindra       0.474334
# ICICI_Bank           0.091036
# AXIS_Bank            0.220274
# Indusind_Bank        1.000000

# %% [markdown]
# <H2> Risk Return Analysis

# %%
fig, ax = pt.subplots(figsize=(8,6))
pt.scatter(rets.mean(), rets.std())
pt.xlabel('Expected returns')
pt.ylabel('Standard deviations/ Risks')
pt.title('Risk and Return Analysis')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    pt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'top',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.2),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

pt.savefig("5 Risk and Return Analysis.png")

# %% [markdown]
# <h3>Steps for regression</h3>
# <li>Construct y (dependent variable series)
# <li>Construct matrix (dataframe) of X (independent variable series)
# <li>Add intercept
# <li>Model the regression
# <li>Get the results
# <h3>The statsmodels library contains various regression packages. We'll use the OLS (Ordinary Least Squares) model

# %%
import numpy as np
import statsmodels.api as sm
X=close_df[['HDFC_Bank','Kotak_Mahindra','AXIS_Bank','Indusind_Bank']]
X = sm.add_constant(X)
y=close_df['ICICI_Bank']
model = sm.OLS(y,X,missing='drop')             #drop rows with missing values
result = model.fit()                           #adjusts the data to model
result.summary()
# Out:
# C:\Users\raisi\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ICICI_Bank   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     229.6
# Date:                Sat, 16 Jun 2018   Prob (F-statistic):           1.52e-51
# Time:                        02:03:51   Log-Likelihood:                -382.74
# No. Observations:                 112   AIC:                             775.5
# Df Residuals:                     107   BIC:                             789.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            114.1276     31.716      3.598      0.000      51.254     177.002
# HDFC_Bank          0.0416      0.032      1.286      0.201      -0.023       0.106
# Kotak_Mahindra     0.0287      0.023      1.261      0.210      -0.016       0.074
# AXIS_Bank          0.5944      0.042     14.322      0.000       0.512       0.677
# Indusind_Bank     -0.1370      0.018     -7.774      0.000      -0.172      -0.102
# ==============================================================================
# Omnibus:                        4.212   Durbin-Watson:                   0.562
# Prob(Omnibus):                  0.122   Jarque-Bera (JB):                4.187
# Skew:                          -0.467   Prob(JB):                        0.123
# Kurtosis:                       2.848   Cond. No.                     1.30e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3>Plotting the Predicted values and actual values to the model

# %%
fig, ax = pt.subplots(figsize=(8,6))
ax.plot(y, color="#2498B0", label="Actual values")
ax.plot(result.fittedvalues, color='#f4c20d', label="Predicted values")
ax.set_xlabel('Dates')
ax.set_ylabel('Closed Prices')
ax.set_title('ICICI Bank Predicted Values')
p,q = ax.get_legend_handles_labels()
ax.legend(p, q)
pt.savefig("6 ICICI Bank Predicted Values")
