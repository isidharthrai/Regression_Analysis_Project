# %% [markdown]
# <h3>Problem: Comparing top five companies of India in Chemicals sector</h4>

# %% [markdown]
# Importing all the modules

# %%
import datetime as dt
import pandas as pd
import pandas_datareader as data
import matplotlib.pyplot as pt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %% [markdown]
# Specifying the Date

# %%
start = dt.datetime(2018, 1, 1)
#end = dt.datetime.today()
end = dt.datetime(2018, 6, 13)

# %% [markdown]
# Collecting the Data set

# %%
com_df1 = pd.DataFrame(data.DataReader('BSE/BOM500331', 'quandl', start=start, end=end )['Close'])    #Pidilite_Ind

# %%
com_df2 = pd.DataFrame(data.DataReader('BSE/BOM512070', 'quandl', start=start, end=end )['Close'])    #UPL

# %%
com_df3 = pd.DataFrame(data.DataReader('BSE/BOM500770', 'quandl', start=start, end=end )['Close'])    #Tata_Chemicals

# %%
com_df4 = pd.DataFrame(data.DataReader('BSE/BOM532725', 'quandl', start=start, end=end )['Close'])    #Solar_Ind

# %%
com_df5 = pd.DataFrame(data.DataReader('BSE/BOM524208', 'quandl', start=start, end=end )['Close'])    #Aarti_Ind

# %% [markdown]
# Renaming the close columns

# %%
Pidilite_Ind = com_df1.rename(columns={'Close':'Pidilite_Ind'})
UPL = com_df2.rename(columns={'Close':'UPL'})
Tata_Chemicals = com_df3.rename(columns={'Close':'Tata_Chemicals'})
Solar_Ind = com_df4.rename(columns={'Close':'Solar_Ind'})
Aarti_Ind = com_df5.rename(columns={'Close':'Aarti_Ind'})

# %% [markdown]
# Joinig all the data frames

# %%
close_df = (((Pidilite_Ind.join(UPL, how="outer")).join(Tata_Chemicals, how="outer")).join(Solar_Ind, how="outer")).join(Aarti_Ind,how="outer")

# %%
close_df
# Out:
#             Pidilite_Ind     UPL  Tata_Chemicals  Solar_Ind  Aarti_Ind
# Date
# 2018-06-13       1081.30  688.20          741.20    1175.55    1275.00
# 2018-06-12       1058.45  689.25          744.35    1183.20    1231.60
# 2018-06-11       1056.30  699.75          732.35    1154.55    1218.75
# 2018-06-08       1070.30  712.45          739.05    1149.80    1175.05
# 2018-06-07       1087.60  702.65          739.50    1164.90    1186.10
# 2018-06-06       1089.65  693.75          730.10    1142.85    1156.40
# 2018-06-05       1091.45  686.50          725.20    1086.90    1165.05
# 2018-06-04       1120.05  688.60          732.65    1122.35    1202.70
# 2018-06-01       1118.40  697.35          735.30    1159.70    1227.75
# 2018-05-31       1155.45  707.20          739.80    1164.50    1243.30
# 2018-05-30       1187.20  705.25          729.40    1161.05    1236.05
# 2018-05-29       1168.95  704.30          725.80    1156.65    1205.00
# 2018-05-28       1155.35  719.00          738.75    1164.70    1219.90
# 2018-05-25       1139.25  697.60          732.70    1145.05    1252.75
# 2018-05-24       1080.05  695.00          716.50    1110.35    1263.30
# 2018-05-23       1084.20  685.05          721.85    1109.95    1242.35
# 2018-05-22       1118.30  683.45          728.45    1121.55    1260.70
# 2018-05-21       1094.80  681.70          734.20    1105.95    1215.05
# 2018-05-18       1079.50  708.65          718.70    1138.45    1260.35
# 2018-05-17       1073.00  708.50          743.20    1116.15    1282.75
# 2018-05-16       1093.70  725.15          729.80    1112.15    1300.10
# 2018-05-15       1090.15  732.55          744.20    1091.15    1297.35
# 2018-05-14       1100.70  727.70          773.45    1065.25    1304.50
# 2018-05-11       1103.90  734.55          775.65    1065.00    1324.80
# 2018-05-10       1085.20  722.15          766.60    1065.85    1319.10
# 2018-05-09       1088.85  731.00          764.05    1057.40    1321.65
# 2018-05-08       1105.60  720.80          765.85    1058.80    1315.85
# 2018-05-07       1079.95  717.50          758.10    1047.70    1320.70
# 2018-05-04       1069.35  703.75          765.40    1057.85    1305.75
# 2018-05-03       1086.40  707.95          767.90    1062.75    1323.30
# ...                  ...     ...             ...        ...        ...
# 2018-02-12        892.25  725.05          715.20    1034.10    1134.75
# 2018-02-09        877.65  710.75          701.40    1034.50    1137.85
# 2018-02-08        884.90  717.35          708.60    1049.40    1136.75
# 2018-02-07        865.85  701.25          681.05    1044.50    1128.20
# 2018-02-06        866.60  700.70          682.95    1020.70    1099.50
# 2018-02-05        875.00  722.55          696.80    1034.70    1096.25
# 2018-02-02        862.10  733.05          690.05    1075.50    1086.75
# 2018-02-01        897.40  758.70          718.35    1083.55    1103.80
# 2018-01-31        896.00  752.35          718.45    1071.85    1057.15
# 2018-01-30        886.25  771.25          714.60    1088.05    1031.65
# 2018-01-29        893.50  786.15          720.90    1099.35    1036.45
# 2018-01-25        877.40  768.65          718.90    1100.40    1083.70
# 2018-01-24        878.10  821.85          728.60    1129.90    1120.75
# 2018-01-23        886.20  806.75          735.80    1137.40    1123.35
# 2018-01-22        895.85  813.90          734.10    1130.05    1135.90
# 2018-01-19        890.30  801.55          725.75    1137.05    1111.25
# 2018-01-18        892.65  798.20          728.65    1135.50    1115.60
# 2018-01-17        896.00  780.95          749.40    1148.80    1114.90
# 2018-01-16        896.35  767.15          739.90    1158.25    1122.65
# 2018-01-15        907.10  772.00          764.90    1160.65    1127.35
# 2018-01-12        907.40  777.85          764.35    1161.55    1125.90
# 2018-01-11        900.30  786.70          770.90    1167.15    1123.80
# 2018-01-10        912.40  779.40          762.95    1169.40    1119.80
# 2018-01-09        914.90  789.20          764.75    1176.15    1137.75
# 2018-01-08        911.75  783.70          767.25    1178.05    1149.90
# 2018-01-05        910.70  774.85          758.05    1174.85    1172.85
# 2018-01-04        907.55  781.15          754.40    1182.60    1150.25
# 2018-01-03        910.95  775.35          756.40    1177.25    1148.85
# 2018-01-02        888.75  772.15          728.50    1170.95    1129.40
# 2018-01-01        900.90  757.25          726.05    1183.65    1139.65
#
# [112 rows x 5 columns]

# %% [markdown]
# Finding Percentage Change of each Company according to previous day

# %%
rets = close_df.pct_change()                                    #returns -- one day percent change for each of the stocks
rets
# Out:
#             Pidilite_Ind       UPL  Tata_Chemicals  Solar_Ind  Aarti_Ind
# Date
# 2018-06-13           NaN       NaN             NaN        NaN        NaN
# 2018-06-12     -0.021132  0.001526        0.004250   0.006508  -0.034039
# 2018-06-11     -0.002031  0.015234       -0.016121  -0.024214  -0.010434
# 2018-06-08      0.013254  0.018149        0.009149  -0.004114  -0.035856
# 2018-06-07      0.016164 -0.013755        0.000609   0.013133   0.009404
# 2018-06-06      0.001885 -0.012666       -0.012711  -0.018929  -0.025040
# 2018-06-05      0.001652 -0.010450       -0.006711  -0.048957   0.007480
# 2018-06-04      0.026204  0.003059        0.010273   0.032616   0.032316
# 2018-06-01     -0.001473  0.012707        0.003617   0.033278   0.020828
# 2018-05-31      0.033128  0.014125        0.006120   0.004139   0.012665
# 2018-05-30      0.027478 -0.002757       -0.014058  -0.002963  -0.005831
# 2018-05-29     -0.015372 -0.001347       -0.004936  -0.003790  -0.025120
# 2018-05-28     -0.011634  0.020872        0.017842   0.006960   0.012365
# 2018-05-25     -0.013935 -0.029764       -0.008190  -0.016871   0.026928
# 2018-05-24     -0.051964 -0.003727       -0.022110  -0.030304   0.008421
# 2018-05-23      0.003842 -0.014317        0.007467  -0.000360  -0.016584
# 2018-05-22      0.031452 -0.002336        0.009143   0.010451   0.014770
# 2018-05-21     -0.021014 -0.002561        0.007893  -0.013909  -0.036210
# 2018-05-18     -0.013975  0.039534       -0.021111   0.029387   0.037282
# 2018-05-17     -0.006021 -0.000212        0.034089  -0.019588   0.017773
# 2018-05-16      0.019292  0.023500       -0.018030  -0.003584   0.013526
# 2018-05-15     -0.003246  0.010205        0.019731  -0.018882  -0.002115
# 2018-05-14      0.009678 -0.006621        0.039304  -0.023736   0.005511
# 2018-05-11      0.002907  0.009413        0.002844  -0.000235   0.015562
# 2018-05-10     -0.016940 -0.016881       -0.011668   0.000798  -0.004303
# 2018-05-09      0.003363  0.012255       -0.003326  -0.007928   0.001933
# 2018-05-08      0.015383 -0.013953        0.002356   0.001324  -0.004388
# 2018-05-07     -0.023200 -0.004578       -0.010119  -0.010484   0.003686
# 2018-05-04     -0.009815 -0.019164        0.009629   0.009688  -0.011320
# 2018-05-03      0.015944  0.005968        0.003266   0.004632   0.013441
# ...                  ...       ...             ...        ...        ...
# 2018-02-12     -0.003907  0.002697        0.004494  -0.022174  -0.040056
# 2018-02-09     -0.016363 -0.019723       -0.019295   0.000387   0.002732
# 2018-02-08      0.008261  0.009286        0.010265   0.014403  -0.000967
# 2018-02-07     -0.021528 -0.022444       -0.038879  -0.004669  -0.007521
# 2018-02-06      0.000866 -0.000784        0.002790  -0.022786  -0.025439
# 2018-02-05      0.009693  0.031183        0.020280   0.013716  -0.002956
# 2018-02-02     -0.014743  0.014532       -0.009687   0.039432  -0.008666
# 2018-02-01      0.040947  0.034991        0.041012   0.007485   0.015689
# 2018-01-31     -0.001560 -0.008370        0.000139  -0.010798  -0.042263
# 2018-01-30     -0.010882  0.025121       -0.005359   0.015114  -0.024121
# 2018-01-29      0.008181  0.019319        0.008816   0.010386   0.004653
# 2018-01-25     -0.018019 -0.022260       -0.002774   0.000955   0.045588
# 2018-01-24      0.000798  0.069212        0.013493   0.026808   0.034188
# 2018-01-23      0.009224 -0.018373        0.009882   0.006638   0.002320
# 2018-01-22      0.010889  0.008863       -0.002310  -0.006462   0.011172
# 2018-01-19     -0.006195 -0.015174       -0.011374   0.006194  -0.021701
# 2018-01-18      0.002640 -0.004179        0.003996  -0.001363   0.003915
# 2018-01-17      0.003753 -0.021611        0.028477   0.011713  -0.000627
# 2018-01-16      0.000391 -0.017671       -0.012677   0.008226   0.006951
# 2018-01-15      0.011993  0.006322        0.033788   0.002072   0.004187
# 2018-01-12      0.000331  0.007578       -0.000719   0.000775  -0.001286
# 2018-01-11     -0.007825  0.011378        0.008569   0.004821  -0.001865
# 2018-01-10      0.013440 -0.009279       -0.010313   0.001928  -0.003559
# 2018-01-09      0.002740  0.012574        0.002359   0.005772   0.016030
# 2018-01-08     -0.003443 -0.006969        0.003269   0.001615   0.010679
# 2018-01-05     -0.001152 -0.011293       -0.011991  -0.002716   0.019958
# 2018-01-04     -0.003459  0.008131       -0.004815   0.006597  -0.019269
# 2018-01-03      0.003746 -0.007425        0.002651  -0.004524  -0.001217
# 2018-01-02     -0.024370 -0.004127       -0.036885  -0.005351  -0.016930
# 2018-01-01      0.013671 -0.019297       -0.003363   0.010846   0.009076
#
# [112 rows x 5 columns]

# %% [markdown]
# <h2>Relationship between Aarti_Ind and other companies

# %% [markdown]
# <h3>Aarti_Ind and Pidilite_Ind</h3>

# %%
pt.plot(rets.Aarti_Ind,rets.Pidilite_Ind, 'o')
pt.xlabel("Aarti_Ind")
pt.ylabel("Pidilite_Ind")
pt.title("Correlation")
pt.savefig("1 Aarti_Ind and Pidilite_Ind.png")

# %% [markdown]
# <h3>Aarti_Ind and UPL</h3>

# %%
pt.plot( rets.Aarti_Ind,rets.UPL,'o')
pt.xlabel("Aarti_Ind")
pt.ylabel("UPL")
pt.title("Correlation")
pt.savefig("2 Aarti_Ind and UPL.png")

# %% [markdown]
# <h3>Aarti_Ind and Tata_Chemicals</h3>

# %%
pt.plot(rets.Aarti_Ind,rets.Tata_Chemicals,'o')
pt.xlabel("Aarti_Ind")
pt.ylabel("Tata_Chemicals")
pt.title("Correlation")
pt.savefig("3 Aarti_Ind and Tata_Chemicals.png")

# %% [markdown]
# <h3>Aarti_Ind and Solar_Ind</h3>

# %%
pt.plot(rets.Aarti_Ind,rets.Solar_Ind, 'o')
pt.xlabel("Aarti_Ind")
pt.ylabel("Solar_Ind")
pt.title("Correlation")
pt.savefig("4 Aarti_Ind and Solar_Ind.png")

# %% [markdown]
# <h2>Correlation Matrix

# %%
rets.corr()
# Out:
#                 Pidilite_Ind       UPL  Tata_Chemicals  Solar_Ind  Aarti_Ind
# Pidilite_Ind        1.000000  0.289184        0.435264   0.191608   0.249848
# UPL                 0.289184  1.000000        0.312835   0.301647   0.221757
# Tata_Chemicals      0.435264  0.312835        1.000000   0.055102   0.198857
# Solar_Ind           0.191608  0.301647        0.055102   1.000000   0.247501
# Aarti_Ind           0.249848  0.221757        0.198857   0.247501   1.000000

# %% [markdown]
# <H2> Risk Return Analysis

# %%
fig, ax = pt.subplots(figsize=(8,6))
pt.scatter(rets.mean(), rets.std())
pt.xlabel('Expected returns')
pt.ylabel('Standard deviations/ Risks')
pt.title('Risk and Return Analysis')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    pt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'top',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.2),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

pt.savefig("5 Risk and Return Analysis.png")

# %% [markdown]
# <h3>Steps for regression</h3>
# <li>Construct y (dependent variable series)
# <li>Construct matrix (dataframe) of X (independent variable series)
# <li>Add intercept
# <li>Model the regression
# <li>Get the results
# <h3>The statsmodels library contains various regression packages. We'll use the OLS (Ordinary Least Squares) model

# %%
import numpy as np
import statsmodels.api as sm
X=close_df[['UPL','Tata_Chemicals','Pidilite_Ind','Solar_Ind']]
X = sm.add_constant(X)
y=close_df['Aarti_Ind']
model = sm.OLS(y,X,missing='drop')             #drop rows with missing values
result = model.fit()                           #adjusts the data to model
result.summary()
# Out:
# C:\Users\raisi\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Aarti_Ind   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     118.5
# Date:                Sun, 17 Jun 2018   Prob (F-statistic):           2.19e-38
# Time:                        08:48:21   Log-Likelihood:                -550.97
# No. Observations:                 112   AIC:                             1112.
# Df Residuals:                     107   BIC:                             1126.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            428.9538     97.262      4.410      0.000     236.143     621.765
# UPL                0.0915      0.132      0.695      0.489      -0.169       0.352
# Tata_Chemicals     1.2262      0.189      6.473      0.000       0.851       1.602
# Pidilite_Ind       0.6031      0.049     12.277      0.000       0.506       0.700
# Solar_Ind         -0.7217      0.074     -9.816      0.000      -0.867      -0.576
# ==============================================================================
# Omnibus:                        9.186   Durbin-Watson:                   0.661
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                9.000
# Skew:                          -0.642   Prob(JB):                       0.0111
# Kurtosis:                       3.527   Cond. No.                     5.42e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.42e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3>Plotting the Predicted values and actual values to the model

# %%
fig, ax = pt.subplots(figsize=(8,6))
ax.plot(y, color="#2498B0", label="Actual values")
ax.plot(result.fittedvalues, color='#f4c20d', label="Predicted values")
ax.set_xlabel('Dates')
ax.set_ylabel('Closed Prices')
ax.set_title('Aarti_Ind Predicted Values')
p,q = ax.get_legend_handles_labels()
ax.legend(p, q)
pt.savefig("6 Aarti_Ind Predicted Values")
