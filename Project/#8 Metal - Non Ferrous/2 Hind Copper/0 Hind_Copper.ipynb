# %% [markdown]
# <h3>Problem: Comparing top five companies of India in Metal - Non Ferrous sector</h4>

# %% [markdown]
# Importing all the modules

# %%
import datetime as dt
import pandas as pd
import pandas_datareader as data
import matplotlib.pyplot as pt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %% [markdown]
# Specifying the Date

# %%
start = dt.datetime(2018, 1, 1)
#end = dt.datetime.today()
end = dt.datetime(2018, 6, 13)

# %% [markdown]
# Collecting the Data set

# %%
com_df1 = pd.DataFrame(data.DataReader('BSE/BOM500188', 'quandl', start=start, end=end )['Close'])    #Hind_Zinc

# %%
com_df2 = pd.DataFrame(data.DataReader('BSE/BOM513599', 'quandl', start=start, end=end )['Close'])    #Hind_Copper

# %%
com_df3 = pd.DataFrame(data.DataReader('BSE/BOM504966', 'quandl', start=start, end=end )['Close'])    #Tinplate

# %%
com_df4 = pd.DataFrame(data.DataReader('BSE/BOM533282', 'quandl', start=start, end=end )['Close'])    #Gravita_India

# %%
com_df5 = pd.DataFrame(data.DataReader('BSE/BOM523539', 'quandl', start=start, end=end )['Close'])    #Precision_Wires

# %% [markdown]
# Renaming the close columns

# %%
Hind_Zinc = com_df1.rename(columns={'Close':'Hind_Zinc'})
Hind_Copper = com_df2.rename(columns={'Close':'Hind_Copper'})
Tinplate = com_df3.rename(columns={'Close':'Tinplate'})
Gravita_India = com_df4.rename(columns={'Close':'Gravita_India'})
Precision_Wires = com_df5.rename(columns={'Close':'Precision_Wires'})

# %% [markdown]
# Joinig all the data frames

# %%
close_df = (((Hind_Zinc.join(Hind_Copper, how="outer")).join(Tinplate, how="outer")).join(Gravita_India, how="outer")).join(Precision_Wires,how="outer")

# %%
close_df
# Out:
#             Hind_Zinc  Hind_Copper  Tinplate  Gravita_India  Precision_Wires
# Date
# 2018-06-13     301.70        71.20    177.25         155.80           285.70
# 2018-06-12     303.80        73.40    178.10         154.45           286.05
# 2018-06-11     301.95        70.30    178.75         153.50           293.60
# 2018-06-08     296.05        70.40    181.75         156.95           256.85
# 2018-06-07     297.75        69.80    183.40         151.10           251.50
# 2018-06-06     297.85        67.35    174.70         148.95           242.50
# 2018-06-05     284.55        64.70    171.90         148.10           243.00
# 2018-06-04     286.20        66.55    180.90         160.10           258.30
# 2018-06-01     290.65        69.10    190.40         168.65           265.45
# 2018-05-31     296.15        70.60    200.40         161.95           275.15
# 2018-05-30     293.90        75.80    200.75         166.75           298.85
# 2018-05-29     289.50        74.95    202.95         167.00           299.60
# 2018-05-28     290.25        71.20    205.80         168.45           277.60
# 2018-05-25     290.10        71.10    196.30         164.55           271.90
# 2018-05-24     284.10        70.35    188.90         165.60           272.15
# 2018-05-23     284.30        70.20    187.90         166.70           277.60
# 2018-05-22     289.10        68.60    192.95         163.65           283.75
# 2018-05-21     290.00        67.85    191.65         160.75           287.60
# 2018-05-18     297.65        69.30    196.20         158.90           299.10
# 2018-05-17     299.80        71.45    200.60         166.40           297.35
# 2018-05-16     297.85        70.20    200.00         174.70           298.80
# 2018-05-15     296.85        70.75    202.15         176.45           301.70
# 2018-05-14     297.20        72.40    198.95         174.80           308.15
# 2018-05-11     299.00        74.05    209.90         178.55           302.00
# 2018-05-10     296.25        71.00    214.25         178.65           301.00
# 2018-05-09     300.05        71.50    220.55         179.55           307.95
# 2018-05-08     301.60        72.10    222.45         181.75           310.40
# 2018-05-07     302.15        70.15    221.65         187.50           308.00
# 2018-05-04     303.85        69.65    221.90         188.55           305.85
# 2018-05-03     309.50        70.60    220.80         192.10           310.30
# ...               ...          ...       ...            ...              ...
# 2018-02-12     307.35        79.80    247.45         151.25           321.05
# 2018-02-09     303.85        79.20    241.05         149.90           270.25
# 2018-02-08     288.20        79.60    239.85         156.05           268.25
# 2018-02-07     288.95        73.95    227.95         157.70           248.55
# 2018-02-06     283.15        73.35    222.15         151.20           236.80
# 2018-02-05     292.80        75.70    232.15         150.10           244.45
# 2018-02-02     294.60        76.15    235.55         155.95           247.35
# 2018-02-01     307.75        80.20    257.10         165.80           262.30
# 2018-01-31     310.05        85.05    255.15         164.65           256.70
# 2018-01-30     311.05        85.25    265.30         174.35           264.50
# 2018-01-29     304.75        85.70    280.00         178.05           273.00
# 2018-01-25     298.25        87.30    285.65         179.00           279.70
# 2018-01-24     293.25        87.45    285.80         179.45           269.50
# 2018-01-23     297.40        90.15    296.05         184.55           272.90
# 2018-01-22     292.80        90.35    300.05         181.05           271.90
# 2018-01-19     300.95        86.85    291.15         178.35           277.65
# 2018-01-18     308.70        87.05    286.90         178.25           278.05
# 2018-01-17     323.15        91.50    292.05         180.80           285.90
# 2018-01-16     316.05        90.45    296.90         179.15           289.20
# 2018-01-15     322.70        93.40    313.65         184.60           291.45
# 2018-01-12     323.55        93.35    310.35         187.15           291.60
# 2018-01-11     319.90        94.65    297.30         186.55           293.95
# 2018-01-10     319.50        94.10    311.75         184.25           291.05
# 2018-01-09     317.00        94.95    268.15         180.40           298.10
# 2018-01-08     317.90        97.60    271.65         182.35           300.15
# 2018-01-05     314.10        99.45    271.90         176.20           293.40
# 2018-01-04     317.30       100.00    276.45         165.90           294.05
# 2018-01-03     311.95        99.90    259.60         160.85           291.75
# 2018-01-02     309.90        97.45    260.20         164.20           292.50
# 2018-01-01     309.10        99.90    262.85         159.10           287.75
#
# [112 rows x 5 columns]

# %% [markdown]
# Finding Percentage Change of each Company according to previous day

# %%
rets = close_df.pct_change()                                    #returns -- one day percent change for each of the stocks
rets
# Out:
#             Hind_Zinc  Hind_Copper  Tinplate  Gravita_India  Precision_Wires
# Date
# 2018-06-13        NaN          NaN       NaN            NaN              NaN
# 2018-06-12   0.006961     0.030899  0.004795      -0.008665         0.001225
# 2018-06-11  -0.006090    -0.042234  0.003650      -0.006151         0.026394
# 2018-06-08  -0.019540     0.001422  0.016783       0.022476        -0.125170
# 2018-06-07   0.005742    -0.008523  0.009078      -0.037273        -0.020829
# 2018-06-06   0.000336    -0.035100 -0.047437      -0.014229        -0.035785
# 2018-06-05  -0.044653    -0.039347 -0.016027      -0.005707         0.002062
# 2018-06-04   0.005799     0.028594  0.052356       0.081026         0.062963
# 2018-06-01   0.015549     0.038317  0.052515       0.053404         0.027681
# 2018-05-31   0.018923     0.021708  0.052521      -0.039727         0.036542
# 2018-05-30  -0.007598     0.073654  0.001747       0.029639         0.086135
# 2018-05-29  -0.014971    -0.011214  0.010959       0.001499         0.002510
# 2018-05-28   0.002591    -0.050033  0.014043       0.008683        -0.073431
# 2018-05-25  -0.000517    -0.001404 -0.046161      -0.023152        -0.020533
# 2018-05-24  -0.020683    -0.010549 -0.037697       0.006381         0.000919
# 2018-05-23   0.000704    -0.002132 -0.005294       0.006643         0.020026
# 2018-05-22   0.016884    -0.022792  0.026876      -0.018296         0.022154
pt.xlabel("Hind_Copper")
pt.ylabel("Hind_Zinc")
pt.title("Correlation")
pt.savefig("1 Hind_Copper and Hind_Zinc.png")

# %% [markdown]
# <h3>Hind_Copper and Tinplate</h3>

# %%
pt.plot( rets.Hind_Copper,rets.Tinplate,'o')
pt.xlabel("Hind_Copper")
pt.ylabel("Tinplate")
pt.title("Correlation")
pt.savefig("2 Hind_Copper and Tinplate.png")

# %% [markdown]
# <h3>Hind_Copper and Gravita_India</h3>

# %%
pt.plot(rets.Hind_Copper,rets.Gravita_India,'o')
pt.xlabel("Hind_Copper")
pt.ylabel("Gravita_India")
pt.title("Correlation")
pt.savefig("3 Hind_Copper and Gravita_India.png")

# %% [markdown]
# <h3>Hind_Copper and Precision_India</h3>

# %%
pt.plot(rets.Hind_Copper,rets.Precision_Wires, 'o')
pt.xlabel("Hind_Copper")
pt.ylabel("Precision_Wires")
pt.title("Correlation")
pt.savefig("4 Hind_Copper and Precision_Wires.png")

# %% [markdown]
# <h2>Correlation Matrix

# %%
rets.corr()
# Out:
#                  Hind_Zinc  Hind_Copper  Tinplate  Gravita_India  \
# Hind_Zinc         1.000000     0.394862  0.385664       0.132435
# Hind_Copper       0.394862     1.000000  0.448872       0.328454
# Tinplate          0.385664     0.448872  1.000000       0.352557
# Gravita_India     0.132435     0.328454  0.352557       1.000000
# Precision_Wires   0.228308     0.297961  0.294552       0.244159
#
#                  Precision_Wires
# Hind_Zinc               0.228308
# Hind_Copper             0.297961
# Tinplate                0.294552
# Gravita_India           0.244159
# Precision_Wires         1.000000

# %% [markdown]
# <H2> Risk Return Analysis

# %%
fig, ax = pt.subplots(figsize=(8,6))
pt.scatter(rets.mean(), rets.std())
pt.xlabel('Expected returns')
pt.ylabel('Standard deviations/ Risks')
pt.title('Risk and Return Analysis')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    pt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'top',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.2),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

pt.savefig("5 Risk and Return Analysis.png")

# %% [markdown]
# <h3>Steps for regression</h3>
# <li>Construct y (dependent variable series)
# <li>Construct matrix (dataframe) of X (independent variable series)
# <li>Add intercept
# <li>Model the regression
# <li>Get the results
# <h3>The statsmodels library contains various regression packages. We'll use the OLS (Ordinary Least Squares) model

# %%
import numpy as np
import statsmodels.api as sm
X=close_df[['Hind_Zinc','Tinplate','Gravita_India','Precision_Wires']]
X = sm.add_constant(X)
y=close_df['Hind_Copper']
model = sm.OLS(y,X,missing='drop')             #drop rows with missing values
result = model.fit()                           #adjusts the data to model
result.summary()
# Out:
# C:\Users\raisi\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Hind_Copper   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.750
# Method:                 Least Squares   F-statistic:                     84.43
# Date:                Sun, 17 Jun 2018   Prob (F-statistic):           3.30e-32
# Time:                        09:49:57   Log-Likelihood:                -330.18
# No. Observations:                 112   AIC:                             670.4
# Df Residuals:                     107   BIC:                             684.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              65.1689     12.850      5.071      0.000      39.694      90.643
# Hind_Zinc          -0.1430      0.051     -2.779      0.006      -0.245      -0.041
# Tinplate            0.2674      0.017     16.061      0.000       0.234       0.300
# Gravita_India      -0.0519      0.043     -1.214      0.228      -0.137       0.033
# Precision_Wires     0.0062      0.030      0.205      0.838      -0.054       0.067
# ==============================================================================
# Omnibus:                       45.929   Durbin-Watson:                   0.310
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.453
# Skew:                           1.728   Prob(JB):                     3.09e-21
# Kurtosis:                       5.881   Cond. No.                     1.47e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3>Plotting the Predicted values and actual values to the model

# %%
fig, ax = pt.subplots(figsize=(8,6))
ax.plot(y, color="#2498B0", label="Actual values")
ax.plot(result.fittedvalues, color='#f4c20d', label="Predicted values")
ax.set_xlabel('Dates')
ax.set_ylabel('Closed Prices')
ax.set_title('Hind_Copper Predicted Values')
p,q = ax.get_legend_handles_labels()
ax.legend(p, q)
pt.savefig("6 Hind_Copper Predicted Values")
