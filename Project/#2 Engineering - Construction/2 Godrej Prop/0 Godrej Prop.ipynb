# %% [markdown]
# <h3>Problem: Comparing top five companies of India in Engineering - Construction sector</h4>

# %% [markdown]
# Importing all the modules

# %%
import datetime as dt
import pandas as pd
import pandas_datareader as data
import matplotlib.pyplot as pt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %% [markdown]
# Specifying the Date

# %%
start = dt.datetime(2018, 1, 1)
#end = dt.datetime.today()
end = dt.datetime(2018, 6, 13)

# %% [markdown]
# Collecting the Data set

# %%
com_df1 = pd.DataFrame(data.DataReader('BSE/BOM532868', 'quandl', start=start, end=end )['Close'])    #DLF

# %%
com_df2 = pd.DataFrame(data.DataReader('BSE/BOM533150', 'quandl', start=start, end=end )['Close'])    #Godrej_Prop

# %%
com_df3 = pd.DataFrame(data.DataReader('BSE/BOM533273', 'quandl', start=start, end=end )['Close'])    #Oberoi_Realty

# %%
com_df4 = pd.DataFrame(data.DataReader('BSE/BOM533274', 'quandl', start=start, end=end )['Close'])    #Prestige_Estate

# %%
com_df5 = pd.DataFrame(data.DataReader('BSE/BOM533033', 'quandl', start=start, end=end )['Close'])    #ISGEC_Heavy_Eng

# %% [markdown]
# Renaming the close columns

# %%
DLF = com_df1.rename(columns={'Close':'DLF'})
Godrej_Prop = com_df2.rename(columns={'Close':'Godrej_Prop'})
Oberoi_Realty = com_df3.rename(columns={'Close':'Oberoi_Realty'})
Prestige_Estate = com_df4.rename(columns={'Close':'Prestige_Estate'})
ISGEC_Heavy_Eng = com_df5.rename(columns={'Close':'ISGEC_Heavy_Eng'})

# %% [markdown]
# Joinig all the data frames

# %%
close_df = (((DLF.join(Godrej_Prop, how="outer")).join(Oberoi_Realty, how="outer")).join(Prestige_Estate, how="outer")).join(ISGEC_Heavy_Eng,how="outer")

# %%
close_df
# Out:
#                DLF  Godrej_Prop  Oberoi_Realty  Prestige_Estate  \
# Date
# 2018-06-13  205.00       767.40         527.85           264.10
# 2018-06-12  205.25       768.30         511.00           261.05
# 2018-06-11  202.45       773.90         510.60           260.65
# 2018-06-08  205.60       787.75         513.40           258.40
# 2018-06-07  203.00       785.70         513.60           255.05
# 2018-06-06  200.55       725.35         508.50           233.85
# 2018-06-05  199.30       705.85         499.85           231.40
# 2018-06-04  199.10       713.00         506.30           229.65
# 2018-06-01  206.95       730.40         510.10           239.55
# 2018-05-31  209.55       731.75         506.60           248.10
# 2018-05-30  208.30       741.05         510.10           260.95
# 2018-05-29  205.50       737.85         511.95           261.35
# 2018-05-28  206.50       734.80         512.65           272.25
# 2018-05-25  202.45       730.55         501.25           270.40
# 2018-05-24  195.90       729.45         497.45           269.85
# 2018-05-23  195.80       741.15         499.75           268.85
# 2018-05-22  198.75       763.10         511.00           272.75
# 2018-05-21  193.90       745.10         517.05           275.55
# 2018-05-18  197.25       777.45         524.50           280.60
# 2018-05-17  205.65       800.30         525.75           281.00
# 2018-05-16  205.75       799.50         531.40           275.95
# 2018-05-15  203.30       800.75         534.30           275.85
# 2018-05-14  206.95       813.85         550.85           285.05
# 2018-05-11  213.65       835.90         529.35           293.75
# 2018-05-10  212.85       864.55         531.60           293.50
# 2018-05-09  221.20       877.95         537.35           292.55
# 2018-05-08  222.40       879.65         514.95           291.25
# 2018-05-07  215.70       851.35         517.55           291.40
# 2018-05-04  211.10       808.90         513.75           290.85
# 2018-01-03          7876.55
# 2018-01-02          7845.10
# 2018-01-01          7887.70
#
# [112 rows x 5 columns]

# %% [markdown]
# Finding Percentage Change of each Company according to previous day

# %%
rets = close_df.pct_change()                                    #returns -- one day percent change for each of the stocks
rets
# Out:
#                  DLF  Godrej_Prop  Oberoi_Realty  Prestige_Estate  \
# Date
# 2018-06-13       NaN          NaN            NaN              NaN
# 2018-06-12  0.001220     0.001173      -0.031922        -0.011549
# 2018-06-11 -0.013642     0.007289      -0.000783        -0.001532
# 2018-06-08  0.015559     0.017896       0.005484        -0.008632
# 2018-06-07 -0.012646    -0.002602       0.000390        -0.012964
# 2018-06-06 -0.012069    -0.076810      -0.009930        -0.083121
# 2018-06-05 -0.006233    -0.026884      -0.017011        -0.010477
# 2018-06-04 -0.001004     0.010130       0.012904        -0.007563
# 2018-06-01  0.039427     0.024404       0.007505         0.043109
# 2018-05-31  0.012563     0.001848      -0.006861         0.035692
# 2018-05-30 -0.005965     0.012709       0.006909         0.051794
# 2018-05-29 -0.013442    -0.004318       0.003627         0.001533
# 2018-05-28  0.004866    -0.004134       0.001367         0.041707
# 2018-05-25 -0.019613    -0.005784      -0.022237        -0.006795
# 2018-05-24 -0.032354    -0.001506      -0.007581        -0.002034
# 2018-05-23 -0.000510     0.016039       0.004624        -0.003706
# 2018-05-22  0.015066     0.029616       0.022511         0.014506
# 2018-05-21 -0.024403    -0.023588       0.011840         0.010266
# 2018-05-18  0.017277     0.043417       0.014409         0.018327
# 2018-05-17  0.042586     0.029391       0.002383         0.001426
# 2018-05-16  0.000486    -0.001000       0.010747        -0.017972
# 2018-05-15 -0.011908     0.001563       0.005457        -0.000362
# 2018-05-14  0.017954     0.016360       0.030975         0.033351
# 2018-05-11  0.032375     0.027093      -0.039031         0.030521
# 2018-05-10 -0.003744     0.034274       0.004250        -0.000851
# 2018-05-09  0.039230     0.015499       0.010816        -0.003237
# 2018-05-08  0.005425     0.001936      -0.041686        -0.004444
# 2018-05-07 -0.030126    -0.032172       0.005049         0.000515
# 2018-05-04 -0.021326    -0.049862      -0.007342        -0.001887
# 2018-05-03  0.012080    -0.029237       0.013820         0.010658
# ...              ...          ...            ...              ...
# 2018-02-12  0.012126    -0.000363      -0.015416        -0.003678
# 2018-02-09 -0.020325     0.014459      -0.013605        -0.032098
# 2018-02-08  0.001529    -0.021529       0.045101        -0.021721
# 2018-02-07 -0.017881    -0.035838      -0.016340        -0.018644
# 2018-02-06 -0.001332    -0.032935      -0.019593        -0.003800
# 2018-02-05  0.013784     0.020003       0.023026         0.054612
# 2018-02-02 -0.021272     0.028839       0.040875         0.027618
# 2018-02-01  0.096796     0.007599       0.064667         0.050232
# 2018-01-31  0.022268    -0.007789       0.011113        -0.016146
# 2018-01-30  0.015588     0.003551      -0.003127        -0.020746
# 2018-01-29  0.000394     0.010741      -0.000665        -0.001739
# 2018-01-25 -0.003147     0.010995       0.014267        -0.003009
# 2018-01-24  0.021902     0.016344       0.021287         0.005401
# 2018-01-23  0.002124     0.010641      -0.062804         0.011376
# 2018-01-22 -0.030636     0.042174      -0.004899        -0.024996
# 2018-01-19 -0.008945    -0.066689      -0.005120         0.006089
# 2018-01-18  0.003410    -0.034359      -0.006333        -0.014174
# 2018-01-17  0.048971     0.046602       0.031172         0.034572
# 2018-01-16 -0.019436    -0.056682       0.008113         0.054029
# 2018-01-15  0.038088     0.061555       0.006706         0.001185
# 2018-01-12  0.004118     0.001442       0.020365        -0.001924
# 2018-01-11  0.008762     0.012240       0.032084         0.018236
# 2018-01-10 -0.004990    -0.025133      -0.048256        -0.026645
# 2018-01-09  0.002600    -0.038307      -0.039024         0.007031
# 2018-01-08 -0.035569    -0.070056      -0.024207        -0.008616
# 2018-01-05 -0.001729    -0.014890      -0.007594         0.005993
# 2018-01-04 -0.008466    -0.010560      -0.003979         0.007447
# 2018-01-03  0.002135    -0.006208      -0.015878        -0.046866
# 2018-01-02 -0.016266    -0.011301       0.003539        -0.000776
# 2018-01-01  0.010630    -0.000639      -0.005394        -0.015523
#
#             ISGEC_Heavy_Eng
# Date
# 2018-06-13              NaN
# 2018-06-12        -0.003400
# 2018-06-11         0.007820
# 2018-06-08        -0.010753
# 2018-06-07         0.014859
# 2018-06-06         0.019753
# 2018-06-05        -0.096504
# 2018-06-04         0.050516
# 2018-06-01         0.045254
# 2018-05-31        -0.027112
# 2018-05-30        -0.005635
# 2018-05-29        -0.003953
# 2018-05-28         0.056473
# 2018-05-25        -0.008521
# 2018-05-24        -0.052932
# 2018-05-23         0.035740
# 2018-05-22         0.009471
# 2018-05-21         0.003809
# 2018-05-18         0.028878
# 2018-05-17        -0.003008
# 2018-05-16        -0.009537
# 2018-05-15         0.014999
# 2018-05-14         0.000678
# 2018-05-11         0.031864
# 2018-05-10         0.001470
# 2018-05-09         0.022718
# 2018-05-08         0.021845
# 2018-05-07        -0.020476
# 2018-05-04        -0.004093
# 2018-05-03         0.019816
# ...                     ...
# 2018-02-12        -0.033059
# 2018-02-09        -0.009792
# 2018-02-08        -0.006925
# 2018-02-07        -0.002721
# 2018-02-06        -0.016779
# 2018-02-05        -0.032194
# 2018-02-02        -0.002535
# 2018-02-01         0.030864
# 2018-01-31         0.008339
# 2018-01-30         0.003694
# 2018-01-29         0.022561
# 2018-01-25         0.045208
# 2018-01-24         0.008643
# 2018-01-23        -0.001994
# 2018-01-22        -0.005060
# 2018-01-19         0.009376
# 2018-01-18         0.007583
# 2018-01-17         0.012557
# 2018-01-16         0.001841
# 2018-01-15         0.005888
# 2018-01-12        -0.019076
# 2018-01-11        -0.000177
# 2018-01-10         0.007831
# 2018-01-09        -0.019948
# 2018-01-08         0.001540
# 2018-01-05         0.003545
# 2018-01-04        -0.033172
# 2018-01-03         0.002590
# 2018-01-02        -0.003993
# 2018-01-01         0.005430
#
# [112 rows x 5 columns]

# %% [markdown]
# <h2>Relationship between Godrej Porp and other companies

# %% [markdown]
# <h3>Godrej Prop and DLF</h3>

# %%
pt.plot(rets.Godrej_Prop,rets.DLF, 'o')
pt.xlabel("Godrej Prop")
pt.ylabel("DLF")
pt.title("Correlation")
pt.savefig("1 Godrej Prop and DLF.png")

# %% [markdown]
# <h3>Godrej Prop and Oberoi Realty</h3>

# %%
pt.plot( rets.Godrej_Prop,rets.Oberoi_Realty,'o')
pt.xlabel("Godrej_Prop")
pt.ylabel("Oberoi_Realty")
pt.title("Correlation")
pt.savefig("2 Godrej_Prop and Oberoi_Realty.png")

# %% [markdown]
# <h3>Godrej Prop and Prestige Estate</h3>

# %%
pt.plot(rets.Godrej_Prop,rets.Prestige_Estate,'o')
pt.xlabel("Godrej Prop")
pt.ylabel("Prestige Estate")
pt.title("Correlation")
pt.savefig("3 Godrej_Prop and Prestige Estate.png")

# %% [markdown]
# <h3>Godrej Prop and ISGEC Heavy Eng</h3>

# %%
pt.plot(rets.Godrej_Prop,rets.ISGEC_Heavy_Eng, 'o')
pt.xlabel("Godrej Prop")
pt.ylabel("ISGEC Heavy Eng")
pt.title("Correlation")
pt.savefig("4 Godrej Prop and ISGEC Heavy Eng.png")

# %% [markdown]
# <h2>Correlation Matrix

# %%
rets.corr()
# Out:
#                       DLF  Godrej_Prop  Oberoi_Realty  Prestige_Estate  \
# DLF              1.000000     0.415396       0.311603         0.336967
# Godrej_Prop      0.415396     1.000000       0.284362         0.245837
# Oberoi_Realty    0.311603     0.284362       1.000000         0.327162
# Prestige_Estate  0.336967     0.245837       0.327162         1.000000
# ISGEC_Heavy_Eng  0.281121     0.201441       0.002105         0.044828
#
#                  ISGEC_Heavy_Eng
# DLF                     0.281121
# Godrej_Prop             0.201441
# Oberoi_Realty           0.002105
# Prestige_Estate         0.044828
# ISGEC_Heavy_Eng         1.000000

# %% [markdown]
# <H2> Risk Return Analysis

# %%
fig, ax = pt.subplots(figsize=(8,6))
pt.scatter(rets.mean(), rets.std())
pt.xlabel('Expected returns')
pt.ylabel('Standard deviations/ Risks')
pt.title('Risk and Return Analysis')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    pt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'top',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.2),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

pt.savefig("5 Risk and Return Analysis.png")

# %% [markdown]
# <h3>Steps for regression</h3>
# <li>Construct y (dependent variable series)
# <li>Construct matrix (dataframe) of X (independent variable series)
# <li>Add intercept
# <li>Model the regression
# <li>Get the results
# <h3>The statsmodels library contains various regression packages. We'll use the OLS (Ordinary Least Squares) model

# %%
import numpy as np
import statsmodels.api as sm
X=close_df[['DLF','Oberoi_Realty','Prestige_Estate','ISGEC_Heavy_Eng']]
X = sm.add_constant(X)
y=close_df['Godrej_Prop']
model = sm.OLS(y,X,missing='drop')             #drop rows with missing values
result = model.fit()                           #adjusts the data to model
result.summary()
# Out:
# C:\Users\raisi\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Godrej_Prop   R-squared:                       0.256
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                     9.212
# Date:                Sat, 16 Jun 2018   Prob (F-statistic):           1.96e-06
# Time:                        12:08:13   Log-Likelihood:                -564.43
# No. Observations:                 112   AIC:                             1139.
# Df Residuals:                     107   BIC:                             1152.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             311.2133     86.956      3.579      0.001     138.833     483.594
# DLF                 0.9929      0.385      2.578      0.011       0.229       1.756
# Oberoi_Realty       0.5051      0.166      3.049      0.003       0.177       0.833
# Prestige_Estate     0.1162      0.318      0.365      0.716      -0.515       0.747
# ISGEC_Heavy_Eng    -0.0074      0.013     -0.548      0.585      -0.034       0.019
# ==============================================================================
# Omnibus:                        3.223   Durbin-Watson:                   0.226
# Prob(Omnibus):                  0.200   Jarque-Bera (JB):                2.617
# Skew:                           0.335   Prob(JB):                        0.270
# Kurtosis:                       3.333   Cond. No.                     1.67e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3>Plotting the Predicted values and actual values to the model

# %%
fig, ax = pt.subplots(figsize=(8,6))
ax.plot(y, color="#2498B0", label="Actual values")
ax.plot(result.fittedvalues, color='#f4c20d', label="Predicted values")
ax.set_xlabel('Dates')
ax.set_ylabel('Closed Prices')
ax.set_title('Godrej Prop Predicted Values')
p,q = ax.get_legend_handles_labels()
ax.legend(p, q)
pt.savefig("6 Godrej Prop Predicted Values")
