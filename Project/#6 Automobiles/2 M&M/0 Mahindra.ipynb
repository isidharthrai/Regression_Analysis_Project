# %% [markdown]
# <h3>Problem: Comparing top five companies of India in Automobiles sector</h4>

# %% [markdown]
# Importing all the modules

# %%
import datetime as dt
import pandas as pd
import pandas_datareader as data
import matplotlib.pyplot as pt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %% [markdown]
# Specifying the Date

# %%
start = dt.datetime(2018, 1, 1)
#end = dt.datetime.today()
end = dt.datetime(2018, 6, 13)

# %% [markdown]
# Collecting the Data set

# %%
com_df1 = pd.DataFrame(data.DataReader('BSE/BOM532500', 'quandl', start=start, end=end )['Close'])    #Maruti_Suzuki

# %%
com_df2 = pd.DataFrame(data.DataReader('BSE/BOM500520', 'quandl', start=start, end=end )['Close'])    #Mahindra

# %%
com_df3 = pd.DataFrame(data.DataReader('BSE/BOM500500', 'quandl', start=start, end=end )['Close'])    #Hind_Motors

# %%
com_df4 = pd.DataFrame(data.DataReader('BSE/BOM532977', 'quandl', start=start, end=end )['Close'])    #Bajaj_Auto

# %%
com_df5 = pd.DataFrame(data.DataReader('BSE/BOM500182', 'quandl', start=start, end=end )['Close'])    #Hero_Motocorp

# %% [markdown]
# Renaming the close columns

# %%
Maruti_Suzuki = com_df1.rename(columns={'Close':'Maruti_Suzuki'})
Mahindra = com_df2.rename(columns={'Close':'Mahindra'})
Hind_Motors = com_df3.rename(columns={'Close':'Hind_Motors'})
Bajaj_Auto = com_df4.rename(columns={'Close':'Bajaj_Auto'})
Hero_Motocorp = com_df5.rename(columns={'Close':'Hero_Motocorp'})

# %% [markdown]
# Joinig all the data frames

# %%
close_df = (((Maruti_Suzuki.join(Mahindra, how="outer")).join(Hind_Motors, how="outer")).join(Bajaj_Auto, how="outer")).join(Hero_Motocorp,how="outer")

# %%
close_df
# Out:
#             Maruti_Suzuki  Mahindra  Hind_Motors  Bajaj_Auto  Hero_Motocorp
# Date
# 2018-06-13        8991.80    917.40         7.21     2908.30        3698.90
# 2018-06-12        9017.20    916.45         7.18     2886.95        3688.75
# 2018-06-11        9021.05    916.60         7.18     2882.00        3612.55
# 2018-06-08        8945.70    910.90         7.14     2875.40        3634.40
# 2018-06-07        8914.50    919.25         7.01     2889.00        3657.05
# 2018-06-06        8871.00    914.70         6.38     2884.55        3638.90
# 2018-06-05        8810.35    901.90         6.60     2844.15        3608.65
# 2018-06-04        8750.35    914.60         6.94     2876.60        3612.00
# 2018-06-01        8792.15    901.55         6.88     2893.25        3623.75
# 2018-05-31        8534.95    923.50         6.92     2752.15        3547.25
# 2018-05-30        8604.60    895.60         6.84     2763.10        3606.85
# 2018-05-29        8681.00    868.80         6.88     2794.00        3612.35
# 2018-05-28        8705.85    849.60         6.93     2791.25        3596.85
# 2018-05-25        8546.85    857.30         6.94     2759.85        3550.70
# 2018-05-24        8409.80    844.20         6.84     2736.70        3486.25
# 2018-05-23        8500.90    831.80         6.74     2775.80        3482.15
# 2018-05-22        8559.40    830.85         6.76     2811.25        3509.30
# 2018-05-21        8428.15    826.70         6.82     2719.90        3495.00
# 2018-05-18        8512.55    834.35         6.98     2777.50        3561.75
# 2018-05-17        8709.80    849.80         7.03     2819.15        3554.45
# 2018-05-16        8698.05    853.00         7.05     2808.25        3576.40
# 2018-05-15        8725.90    848.65         7.01     2827.80        3653.25
# 2018-05-14        8715.15    850.10         7.15     2834.70        3649.35
# 2018-05-11        8738.30    869.00         7.02     2816.45        3616.15
# 2018-05-10        8707.60    856.40         7.21     2827.80        3643.25
# 2018-05-09        8713.60    860.05         7.44     2874.25        3657.35
# 2018-05-08        8775.15    865.60         7.26     2891.75        3656.65
# 2018-05-07        8742.40    885.60         7.10     2917.05        3655.05
# 2018-05-04        8679.05    854.20         7.08     2890.50        3659.80
# 2018-05-03        8756.15    863.05         7.18     2971.90        3657.10
# ...                   ...       ...          ...         ...            ...
# 2018-02-12        9106.10    746.70         9.25     3143.35        3619.35
# 2018-02-09        8946.45    749.95         8.82     3103.50        3546.05
# 2018-02-08        9027.05    753.75         8.64     3152.40        3585.25
# 2018-02-07        8919.90    747.10         8.24     3137.30        3564.30
# 2018-02-06        8984.45    754.35         8.17     3138.20        3542.65
# 2018-02-05        9088.70    760.70         8.52     3177.80        3634.05
# 2018-02-02        9000.30    768.50         8.88     3242.60        3623.65
# 2018-02-01        9402.95    797.35         9.13     3409.50        3734.40
# 2018-01-31        9514.15    763.45         8.84     3338.80        3691.60
# 2018-01-30        9569.80    763.45         9.04     3351.40        3688.50
# 2018-01-29        9634.50    763.75         9.17     3362.10        3640.00
# 2018-01-25        9277.20    755.45         9.37     3303.20        3569.60
# 2018-01-24        9427.75    756.25         9.63     3335.60        3640.50
# 2018-01-23        9397.00    768.50         9.72     3294.30        3623.10
# 2018-01-22        9306.65    759.85         9.55     3272.10        3602.80
# 2018-01-19        9321.35    763.90         9.98     3208.05        3590.75
# 2018-01-18        9359.00    758.70        10.42     3195.40        3592.20
# 2018-01-17        9312.00    745.05        10.96     3184.90        3566.05
# 2018-01-16        9320.50    748.45        11.43     3160.00        3594.85
# 2018-01-15        9356.45    759.10        12.69     3163.30        3627.75
# 2018-01-12        9460.30    766.10        14.07     3175.10        3685.80
# 2018-01-11        9341.50    764.90        12.62     3202.00        3706.00
# 2018-01-10        9384.15    758.25        10.52     3205.35        3732.20
# 2018-01-09        9386.75    760.50        10.25     3240.95        3751.85
# 2018-01-08        9449.20    759.80        10.07     3275.35        3790.35
# 2018-01-05        9434.05    756.30         9.30     3277.55        3739.30
# 2018-01-04        9382.25    755.00         9.32     3262.75        3738.50
# 2018-01-03        9416.75    754.65         9.62     3247.45        3751.45
# 2018-01-02        9545.15    752.50         9.62     3294.15        3747.45
# 2018-01-01        9665.45    745.50         9.74     3293.40        3768.80
#
# [112 rows x 5 columns]

# %% [markdown]
# Finding Percentage Change of each Company according to previous day

# %%
rets = close_df.pct_change()                                    #returns -- one day percent change for each of the stocks
rets
# Out:
#             Maruti_Suzuki  Mahindra  Hind_Motors  Bajaj_Auto  Hero_Motocorp
# Date
# 2018-06-13            NaN       NaN          NaN         NaN            NaN
# 2018-06-12       0.002825 -0.001036    -0.004161   -0.007341      -0.002744
# 2018-06-11       0.000427  0.000164     0.000000   -0.001715      -0.020657
# 2018-06-08      -0.008353 -0.006219    -0.005571   -0.002290       0.006048
# 2018-06-07      -0.003488  0.009167    -0.018207    0.004730       0.006232
# 2018-06-06      -0.004880 -0.004950    -0.089872   -0.001540      -0.004963
# 2018-06-05      -0.006837 -0.013994     0.034483   -0.014006      -0.008313
# 2018-06-04      -0.006810  0.014081     0.051515    0.011409       0.000928
# 2018-06-01       0.004777 -0.014269    -0.008646    0.005788       0.003253
# 2018-05-31      -0.029253  0.024347     0.005814   -0.048769      -0.021111
# 2018-05-30       0.008161 -0.030211    -0.011561    0.003979       0.016802
# 2018-05-29       0.008879 -0.029924     0.005848    0.011183       0.001525
# 2018-05-28       0.002863 -0.022099     0.007267   -0.000984      -0.004291
# 2018-05-25      -0.018264  0.009063     0.001443   -0.011249      -0.012831
# 2018-05-24      -0.016035 -0.015281    -0.014409   -0.008388      -0.018151
# 2018-05-23       0.010833 -0.014688    -0.014620    0.014287      -0.001176
# 2018-05-22       0.006882 -0.001142     0.002967    0.012771       0.007797
# 2018-05-21      -0.015334 -0.004995     0.008876   -0.032494      -0.004075
# 2018-05-18       0.010014  0.009254     0.023460    0.021177       0.019099
# 2018-05-17       0.023172  0.018517     0.007163    0.014995      -0.002050
# 2018-05-16      -0.001349  0.003766     0.002845   -0.003866       0.006175
# 2018-05-15       0.003202 -0.005100    -0.005674    0.006962       0.021488
# 2018-05-14      -0.001232  0.001709     0.019971    0.002440      -0.001068
# 2018-05-11       0.002656  0.022233    -0.018182   -0.006438      -0.009098
# 2018-05-10      -0.003513 -0.014499     0.027066    0.004030       0.007494
# 2018-05-09       0.000689  0.004262     0.031900    0.016426       0.003870
# 2018-05-08       0.007064  0.006453    -0.024194    0.006089      -0.000191
# 2018-05-07      -0.003732  0.023105    -0.022039    0.008749      -0.000438
# 2018-05-04      -0.007246 -0.035456    -0.002817   -0.009102       0.001300
# 2018-05-03       0.008883  0.010361     0.014124    0.028161      -0.000738
# ...                   ...       ...          ...         ...            ...
# 2018-02-12       0.010666  0.000335    -0.047374    0.010447       0.005417
# 2018-02-09      -0.017532  0.004352    -0.046486   -0.012678      -0.020252
# 2018-02-08       0.009009  0.005067    -0.020408    0.015756       0.011055
# 2018-02-07      -0.011870 -0.008823    -0.046296   -0.004790      -0.005843
# 2018-02-06       0.007237  0.009704    -0.008495    0.000287      -0.006074
# 2018-02-05       0.011603  0.008418     0.042840    0.012619       0.025800
# 2018-02-02      -0.009726  0.010254     0.042254    0.020391      -0.002862
# 2018-02-01       0.044737  0.037541     0.028153    0.051471       0.030563
# 2018-01-31       0.011826 -0.042516    -0.031763   -0.020736      -0.011461
# 2018-01-30       0.005849  0.000000     0.022624    0.003774      -0.000840
# 2018-01-29       0.006761  0.000393     0.014381    0.003193      -0.013149
# 2018-01-25      -0.037085 -0.010867     0.021810   -0.017519      -0.019341
# 2018-01-24       0.016228  0.001059     0.027748    0.009809       0.019862
# 2018-01-23      -0.003262  0.016198     0.009346   -0.012382      -0.004780
# 2018-01-22      -0.009615 -0.011256    -0.017490   -0.006739      -0.005603
# 2018-01-19       0.001580  0.005330     0.045026   -0.019575      -0.003345
# 2018-01-18       0.004039 -0.006807     0.044088   -0.003943       0.000404
# 2018-01-17      -0.005022 -0.017991     0.051823   -0.003286      -0.007280
# 2018-01-16       0.000913  0.004563     0.042883   -0.007818       0.008076
# 2018-01-15       0.003857  0.014229     0.110236    0.001044       0.009152
# 2018-01-12       0.011099  0.009221     0.108747    0.003730       0.016002
# 2018-01-11      -0.012558 -0.001566    -0.103056    0.008472       0.005480
# 2018-01-10       0.004566 -0.008694    -0.166403    0.001046       0.007070
# 2018-01-09       0.000277  0.002967    -0.025665    0.011106       0.005265
# 2018-01-08       0.006653 -0.000920    -0.017561    0.010614       0.010262
# 2018-01-05      -0.001603 -0.004606    -0.076465    0.000672      -0.013468
# 2018-01-04      -0.005491 -0.001719     0.002151   -0.004516      -0.000214
# 2018-01-03       0.003677 -0.000464     0.032189   -0.004689       0.003464
# 2018-01-02       0.013635 -0.002849     0.000000    0.014381      -0.001066
# 2018-01-01       0.012603 -0.009302     0.012474   -0.000228       0.005697
#
# [112 rows x 5 columns]

# %% [markdown]
# <h2>Relationship between Mahindra and other companies

# %% [markdown]
# <h3>Mahindra and Maruti_Suzuki</h3>

# %%
pt.plot(rets.Mahindra,rets.Maruti_Suzuki, 'o')
pt.xlabel("Mahindra")
pt.ylabel("Maruti_Suzuki")
pt.title("Correlation")
pt.savefig("1 Mahindra and Maruti_Suzuki.png")

# %% [markdown]
# <h3>Mahindra and Hind Motors</h3>

# %%
pt.plot( rets.Mahindra,rets.Hind_Motors,'o')
pt.xlabel("Mahindra")
pt.ylabel("Hind_Motors")
pt.title("Correlation")
pt.savefig("2 Mahindra and Hind_Motors.png")

# %% [markdown]
# <h3>Mahindra and Bajaj Auto</h3>

# %%
pt.plot(rets.Mahindra,rets.Bajaj_Auto,'o')
pt.xlabel("Mahindra")
pt.ylabel("Bajaj_Auto")
pt.title("Correlation")
pt.savefig("3 Mahindra and Bajaj_Auto.png")

# %% [markdown]
# <h3>Mahindra and Hero_Motocorp</h3>

# %%
pt.plot(rets.Mahindra,rets.Hero_Motocorp, 'o')
pt.xlabel("Mahindra")
pt.ylabel("Hero_Motocorp")
pt.title("Correlation")
pt.savefig("4 Mahindra and Hero_Motocorp.png")

# %% [markdown]
# <h2>Correlation Matrix

# %%
rets.corr()
# Out:
#                Maruti_Suzuki  Mahindra  Hind_Motors  Bajaj_Auto  Hero_Motocorp
# Maruti_Suzuki       1.000000  0.252971     0.155721    0.532836       0.549594
# Mahindra            0.252971  1.000000     0.138666    0.277959       0.190102
# Hind_Motors         0.155721  0.138666     1.000000    0.091060       0.148008
# Bajaj_Auto          0.532836  0.277959     0.091060    1.000000       0.512135
# Hero_Motocorp       0.549594  0.190102     0.148008    0.512135       1.000000

# %% [markdown]
# <H2> Risk Return Analysis

# %%
fig, ax = pt.subplots(figsize=(8,6))
pt.scatter(rets.mean(), rets.std())
pt.xlabel('Expected returns')
pt.ylabel('Standard deviations/ Risks')
pt.title('Risk and Return Analysis')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    pt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'top',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.2),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

pt.savefig("5 Risk and Return Analysis.png")

# %% [markdown]
# <h3>Steps for regression</h3>
# <li>Construct y (dependent variable series)
# <li>Construct matrix (dataframe) of X (independent variable series)
# <li>Add intercept
# <li>Model the regression
# <li>Get the results
# <h3>The statsmodels library contains various regression packages. We'll use the OLS (Ordinary Least Squares) model

# %%
import numpy as np
import statsmodels.api as sm
X=close_df[['Maruti_Suzuki','Hind_Motors','Bajaj_Auto','Hero_Motocorp']]
X = sm.add_constant(X)
y=close_df['Mahindra']
model = sm.OLS(y,X,missing='drop')             #drop rows with missing values
result = model.fit()                           #adjusts the data to model
result.summary()
# Out:
# C:\Users\raisi\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Mahindra   R-squared:                       0.420
# Model:                            OLS   Adj. R-squared:                  0.398
# Method:                 Least Squares   F-statistic:                     19.38
# Date:                Sun, 17 Jun 2018   Prob (F-statistic):           5.10e-12
# Time:                        07:43:49   Log-Likelihood:                -588.08
# No. Observations:                 112   AIC:                             1186.
# Df Residuals:                     107   BIC:                             1200.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           402.1382    187.675      2.143      0.034      30.095     774.182
# Maruti_Suzuki    -0.0544      0.032     -1.700      0.092      -0.118       0.009
# Hind_Motors     -21.3437      5.336     -4.000      0.000     -31.921     -10.766
# Bajaj_Auto        0.0205      0.042      0.485      0.629      -0.063       0.104
# Hero_Motocorp     0.2739      0.072      3.801      0.000       0.131       0.417
# ==============================================================================
# Omnibus:                        2.817   Durbin-Watson:                   0.133
# Prob(Omnibus):                  0.245   Jarque-Bera (JB):                2.839
# Skew:                           0.360   Prob(JB):                        0.242
# Kurtosis:                       2.702   Cond. No.                     4.26e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3>Plotting the Predicted values and actual values to the model

# %%
fig, ax = pt.subplots(figsize=(8,6))
ax.plot(y, color="#2498B0", label="Actual values")
ax.plot(result.fittedvalues, color='#f4c20d', label="Predicted values")
ax.set_xlabel('Dates')
ax.set_ylabel('Closed Prices')
ax.set_title('Mahindra Predicted Values')
p,q = ax.get_legend_handles_labels()
ax.legend(p, q)
pt.savefig("6 Mahindra Predicted Values")
